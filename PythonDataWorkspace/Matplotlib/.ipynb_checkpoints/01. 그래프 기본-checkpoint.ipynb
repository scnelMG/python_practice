# %% [markdown]
# # Matplotlib
# 다양한 형태의 그래프를 통해 데이터 시각화를 할 수 있는 라이브러리

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # 1. 그래프 기본

# %%
x = [1, 2, 3]
y = [2, 4, 8]
plt.plot(x,y)

# %%
plt.plot(x,y)
plt.show()

# %% [markdown]
# ## title 설정

# %%
plt.plot(x,y)
plt.title("Line Graph")
# Out:
# Text(0.5, 1.0, 'Line Graph')

# %%
plt.plot(x,y)
plt.title("꺾은선 그래프")
# Out:
# Text(0.5, 1.0, '꺾은선 그래프')
# C:\anaconda3\envs\practice\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 44734 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\anaconda3\envs\practice\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 51008 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\anaconda3\envs\practice\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 49440 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\anaconda3\envs\practice\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 44536 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\anaconda3\envs\practice\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 47000 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\anaconda3\envs\practice\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 54532 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\anaconda3\envs\practice\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 44734 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\anaconda3\envs\practice\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 51008 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\anaconda3\envs\practice\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 49440 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\anaconda3\envs\practice\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 44536 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\anaconda3\envs\practice\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 47000 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\anaconda3\envs\practice\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 54532 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# ## 한글 폰트 설정

# %%
import matplotlib
matplotlib.rcParams['font.family'] = 'Malgun Gothic' # Windows
#matplotlib.rcParams['font.family'] = 'AppleGothic' # MAc
matplotlib.rcParams['font.size'] = 15 # 글자 크기
matplotlib.rcParams['axes.unicode_minus'] = False # 한글 폰트 사용 시, 마이너스 글자가 깨지는 현상 해결

# %%
import matplotlib.font_manager as fm
fm.fontManager.ttflist # 사용 가능한 폰트 확인
[f.name for f in fm.fontManager.ttflist]
# Out:
# ['DejaVu Sans',
#  'DejaVu Serif',
#  'STIXGeneral',
#  'DejaVu Sans Display',
#  'cmsy10',
#  'cmmi10',
#  'DejaVu Sans Mono',
#  'STIXSizeOneSym',
#  'STIXNonUnicode',
#  'STIXSizeTwoSym',
#  'DejaVu Serif',
#  'STIXGeneral',
#  'DejaVu Sans',
#  'DejaVu Sans',
#  'DejaVu Sans',
#  'DejaVu Sans Mono',
#  'STIXNonUnicode',
#  'STIXSizeThreeSym',
#  'DejaVu Sans Mono',
#  'STIXNonUnicode',
#  'STIXSizeFourSym',
#  'STIXGeneral',
#  'STIXSizeFiveSym',
#  'cmtt10',
#  'cmss10',
#  'STIXSizeFourSym',
#  'STIXNonUnicode',
#  'STIXSizeOneSym',
#  'cmex10',
#  'STIXSizeThreeSym',
#  'STIXGeneral',
#  'DejaVu Serif',
#  'cmr10',
#  'DejaVu Serif',
#  'STIXSizeTwoSym',
#  'cmb10',
#  'DejaVu Sans Mono',
#  'DejaVu Serif Display',
#  'Perpetua',
#  'Lucida Sans Typewriter',
#  'Times New Roman',
#  'Copperplate Gothic Bold',
#  'Leelawadee UI',
#  'Segoe UI',
#  'Niagara Engraved',
#  'Lucida Console',
#  'Gill Sans MT',
#  'Candara',
#  'HYGothic-Extra',
#  'MoeumT R',
#  'Segoe UI',
#  'Century Schoolbook',
#  'Perpetua',
#  'Consolas',
#  'Eras Light ITC',
#  'Cambria',
#  'Gill Sans Ultra Bold',
#  'HancomEQN',
#  'Segoe UI',
#  'Elephant',
#  'Segoe UI',
#  'Lucida Sans',
#  'High Tower Text',
#  'Cambria',
#  'Cooper Black',
#  'Georgia',
#  'Franklin Gothic Medium Cond',
#  'Book Antiqua',
#  'Georgia',
#  'Matura MT Script Capitals',
#  'Haan Wing2',
#  'Gill Sans MT',
#  'Courier New',
#  'Garamond',
#  'Book Antiqua',
#  'Candara',
#  'Microsoft YaHei',
#  'Calisto MT',
#  'Magic R',
#  'Microsoft Tai Le',
#  'Microsoft PhagsPa',
#  'Bodoni MT',
#  'Gigi',
#  'Yu Gothic',
#  'Century Schoolbook',
#  'Niagara Solid',
#  'Curlz MT',
#  'Gill Sans MT Condensed',
#  'Segoe UI',
#  'HYPost-Medium',
#  'Script MT Bold',
#  'Lucida Sans Typewriter',
#  'Arial',
#  'Bodoni MT',
#  'Garamond',
#  'OCR A Extended',
#  'Snap ITC',
#  'Microsoft JhengHei',
#  'Trebuchet MS',
#  'Myanmar Text',
#  'Segoe UI Emoji',
#  'Bookshelf Symbol 7',
#  'Microsoft YaHei',
#  'Constantia',
#  'Hancom Gothic',
#  'Palatino Linotype',
#  'Constantia',
#  'Gill Sans MT Condensed',
#  'Verdana',
#  'Candara',
#  'Sitka Small',
#  'Lucida Sans Typewriter',
#  'Script MT Bold',
#  'Cambria',
#  'Calibri',
#  'Myanmar Text',
#  'Century Schoolbook',
#  'Candara',
#  'Palatino Linotype',
#  'Myanmar Text',
#  'Eras Bold ITC',
#  'Footlight MT Light',
#  'Trebuchet MS',
#  'Segoe Print',
#  'HYMyeongJo-Extra',
#  'Wingdings',
#  'Gigi',
#  'Century Gothic',
#  'Microsoft Tai Le',
#  'HYPMokGak-Bold',
#  'OCR A Extended',
#  'HYPost-Medium',
#  'Trebuchet MS',
#  'Malgun Gothic',
#  'Bodoni MT',
#  'Palatino Linotype',
#  'Comic Sans MS',
#  'Rockwell',
#  'Gill Sans MT',
#  'Times New Roman',
#  'Verdana',
#  'Stencil',
#  'Felix Titling',
#  'Yu Gothic',
#  'Wingdings',
#  'Gulim',
#  'Lucida Bright',
#  'Stencil',
#  'Cambria',
#  'Microsoft JhengHei',
#  'Segoe Print',
#  'Wingdings 3',
#  'Segoe UI',
#  'Sitka Small',
#  'Hancom Gothic',
#  'Haettenschweiler',
#  'Segoe UI',
#  'HYShortSamul-Medium',
#  'Berlin Sans FB Demi',
#  'HCR Batang Ext',
#  'Arial',
#  'HancomEQN',
#  'Malgun Gothic',
#  'Bodoni MT',
#  'Impact',
#  'HCR Batang',
#  'HYHeadLine-Medium',
#  'Book Antiqua',
#  'Vivaldi',
#  'SimSun-ExtB',
#  'Franklin Gothic Demi',
#  'Corbel',
#  'Tw Cen MT',
#  'HCR Dotum',
#  'Poor Richard',
#  'Tw Cen MT Condensed',
#  'French Script MT',
#  'Constantia',
#  'Californian FB',
#  'Lucida Sans Unicode',
#  'Arial',
#  'Century Gothic',
#  'Courier New',
#  'HYGothic-Extra',
#  'HCR Batang ExtB',
#  'Leelawadee UI',
#  'Franklin Gothic Demi',
#  'Baskerville Old Face',
#  'Hancom Gothic',
#  'Arial',
#  'Bookman Old Style',
#  'Felix Titling',
#  'HYGraphic-Medium',
#  'Times New Roman',
#  'Gadugi',
#  'Ebrima',
#  'Malgun Gothic',
#  'Century Gothic',
#  'Century',
#  'HCR Dotum',
#  'Ravie',
#  'Berlin Sans FB',
#  'Rockwell',
#  'Bell MT',
#  'Berlin Sans FB',
#  'Calibri',
#  'Papyrus',
#  'Tw Cen MT',
#  'Malgun Gothic',
#  'Lucida Fax',
#  'Segoe UI',
#  'Franklin Gothic Heavy',
#  'Georgia',
#  'Bell MT',
#  'Colonna MT',
#  'Constantia',
#  'Juice ITC',
#  'Gill Sans MT',
#  'Microsoft Himalaya',
#  'Verdana',
#  'Corbel',
#  'Harlow Solid Italic',
#  'Arial',
#  'Corbel',
#  'Arial',
#  'Yet R',
#  'Segoe UI',
#  'Yet R',
#  'Tw Cen MT',
#  'Lucida Sans Unicode',
#  'Segoe MDL2 Assets',
#  'HCR Dotum',
#  'Imprint MT Shadow',
#  'Segoe UI',
#  'Goudy Old Style',
#  'Webdings',
#  'Perpetua Titling MT',
#  'Times New Roman',
#  'Bell MT',
#  'Bodoni MT',
#  'Bernard MT Condensed',
#  'Dubai',
#  'Franklin Gothic Demi',
#  'Microsoft JhengHei',
#  'Franklin Gothic Medium',
#  'Ebrima',
#  'Symbol',
#  'Comic Sans MS',
#  'Tahoma',
#  'Onyx',
#  'Segoe UI',
#  'Eras Bold ITC',
#  'Eras Medium ITC',
#  'MS Outlook',
#  'Microsoft Yi Baiti',
#  'Rockwell Extra Bold',
#  'Palatino Linotype',
#  'Ebrima',
#  'Segoe MDL2 Assets',
#  'Edwardian Script ITC',
#  'Mistral',
#  'Constantia',
#  'Playbill',
#  'Tw Cen MT',
#  'Corbel',
#  'Lucida Sans',
#  'Vivaldi',
#  'Dubai',
#  'Castellar',
#  'Yu Gothic',
#  'High Tower Text',
#  'Franklin Gothic Book',
#  'Georgia',
#  'Calisto MT',
#  'HYHeadLine-Medium',
#  'HCR Dotum Ext',
#  'Franklin Gothic Demi Cond',
#  'Comic Sans MS',
#  'Headline R',
#  'Californian FB',
#  'Old English Text MT',
#  'Arial',
#  'Perpetua Titling MT',
#  'Modern No. 20',
#  'Segoe UI Emoji',
#  'Century Gothic',
#  'HYShortSamul-Medium',
#  'Calisto MT',
#  'Bodoni MT',
#  'Trebuchet MS',
#  'Franklin Gothic Book',
#  'Tw Cen MT',
#  'HCR Batang',
#  'Mistral',
#  'Sylfaen',
#  'Dubai',
#  'Perpetua',
#  'HYGothic-Medium',
#  'Bodoni MT',
#  'Segoe UI Symbol',
#  'Segoe Script',
#  'Informal Roman',
#  'Rockwell',
#  'Lucida Sans Typewriter',
#  'HCR Dotum',
#  'Microsoft Tai Le',
#  'Goudy Old Style',
#  'Corbel',
#  'Britannic Bold',
#  'Forte',
#  'Harlow Solid Italic',
#  'Wingdings 2',
#  'Leelawadee UI',
#  'Gabriola',
#  'Dubai',
#  'Candara',
#  'Segoe UI Historic',
#  'Times New Roman',
#  'Lucida Bright',
#  'Agency FB',
#  'Eras Medium ITC',
#  'Brush Script MT',
#  'Engravers MT',
#  'Consolas',
#  'Bell MT',
#  'Bookshelf Symbol 7',
#  'Rockwell',
#  'Colonna MT',
#  'Pyunji R',
#  'Bahnschrift',
#  'Jokerman',
#  'Gill Sans MT',
#  'Lucida Calligraphy',
#  'Monotype Corsiva',
#  'Gill Sans MT',
#  'Microsoft New Tai Lue',
#  'Century Gothic',
#  'Edwardian Script ITC',
#  'Calibri',
#  'Segoe UI',
#  'Gill Sans Ultra Bold Condensed',
#  'Bodoni MT',
#  'Lucida Sans',
#  'Microsoft Tai Le',
#  'Dubai',
#  'Matura MT Script Capitals',
#  'Segoe UI',
#  'Bauhaus 93',
#  'Bodoni MT',
#  'Franklin Gothic Medium',
#  'Goudy Old Style',
#  'Bodoni MT',
#  'Segoe UI',
#  'Bodoni MT',
#  'Lucida Sans Typewriter',
#  'Pristina',
#  'Elephant',
#  'Nirmala UI',
#  'MingLiU-ExtB',
#  'Dubai',
#  'Microsoft YaHei',
#  'Chiller',
#  'Yu Gothic',
#  'Lucida Sans Typewriter',
#  'Leelawadee UI',
#  'Chiller',
#  'Bahnschrift',
#  'Lucida Sans',
#  'Tahoma',
#  'HYPost-Light',
#  'Wingdings 3',
#  'Garamond',
#  'MS Reference Sans Serif',
#  'Gabriola',
#  'Wide Latin',
#  'HyhwpEQ',
#  'Bell MT',
#  'Georgia',
#  'Microsoft New Tai Lue',
#  'Book Antiqua',
#  'Eras Demi ITC',
#  'HyhwpEQ',
#  'Constantia',
#  'Ami R',
#  'Gill Sans MT',
#  'Agency FB',
#  'French Script MT',
#  'Nirmala UI',
#  'Snap ITC',
#  'Magic R',
#  'Constantia',
#  'Blackadder ITC',
#  'Cambria',
#  'Californian FB',
#  'Microsoft Sans Serif',
#  'Rockwell',
#  'Impact',
#  'Century Schoolbook',
#  'Sitka Small',
#  'Microsoft PhagsPa',
#  'Perpetua',
#  'Rockwell Condensed',
#  'Ink Free',
#  'Bodoni MT',
#  'Corbel',
#  'Microsoft YaHei',
#  'Bookman Old Style',
#  'Perpetua Titling MT',
#  'HCR Batang ExtB',
#  'Microsoft JhengHei',
#  'HYGraphic-Medium',
#  'Tw Cen MT',
#  'Gadugi',
#  'Tempus Sans ITC',
#  'HYGungSo-Bold',
#  'Gill Sans Ultra Bold Condensed',
#  'Calibri',
#  'Headline R',
#  'Microsoft JhengHei',
#  'Symbol',
#  'Trebuchet MS',
#  'Rockwell Condensed',
#  'Corbel',
#  'Tw Cen MT Condensed',
#  'Kristen ITC',
#  'Bookman Old Style',
#  'Informal Roman',
#  'Yu Gothic',
#  'Lucida Bright',
#  'Palatino Linotype',
#  'Georgia',
#  'Courier New',
#  'Calibri',
#  'NewJumja',
#  'Sitka Small',
#  'Dubai',
#  'Blackadder ITC',
#  'Segoe UI',
#  'Palatino Linotype',
#  'Calibri',
#  'Arial',
#  'Elephant',
#  'Franklin Gothic Heavy',
#  'Century',
#  'Arial',
#  'Perpetua',
#  'Garamond',
#  'Californian FB',
#  'Lucida Bright',
#  'Elephant',
#  'Old English Text MT',
#  'Franklin Gothic Heavy',
#  'Bodoni MT',
#  'Britannic Bold',
#  'Arial',
#  'Franklin Gothic Medium',
#  'HCR Dotum Ext',
#  'HoloLens MDL2 Assets',
#  'Bauhaus 93',
#  'Tw Cen MT Condensed Extra Bold',
#  'Broadway',
#  'Freestyle Script',
#  'Calisto MT',
#  'Segoe Script',
#  'Batang',
#  'Cambria',
#  'Modern No. 20',
#  'Castellar',
#  'Lucida Handwriting',
#  'Copperplate Gothic Bold',
#  'MS Outlook',
#  'Mongolian Baiti',
#  'Segoe Print',
#  'Segoe UI',
#  'Pristina',
#  'Calibri',
#  'Engravers MT',
#  'Tw Cen MT Condensed',
#  'Algerian',
#  'Wide Latin',
#  'Bernard MT Condensed',
#  'Calibri',
#  'HYSinMyeongJo-Medium',
#  'Sitka Small',
#  'Copperplate Gothic Light',
#  'Gill Sans MT Ext Condensed Bold',
#  'MT Extra',
#  'Lucida Handwriting',
#  'NewJumja',
#  'Bradley Hand ITC',
#  'Courier New',
#  'Microsoft JhengHei',
#  'MV Boli',
#  'Rockwell',
#  'Pyunji R',
#  'Algerian',
#  'Wingdings 2',
#  'MoeumT R',
#  'Bodoni MT',
#  'Bodoni MT',
#  'HYPost-Light',
#  'Vladimir Script',
#  'HCR Batang ExtB',
#  'Book Antiqua',
#  'Rage Italic',
#  'HCR Batang',
#  'Verdana',
#  'MingLiU-ExtB',
#  'Calibri',
#  'SimSun',
#  'Batang',
#  'New Gulim',
#  'Gadugi',
#  'Brush Script MT',
#  'Microsoft PhagsPa',
#  'Footlight MT Light',
#  'Arial',
#  'Lucida Sans',
#  'Century Gothic',
#  'Consolas',
#  'HYGothic-Medium',
#  'Candara',
#  'Lucida Bright',
#  'Franklin Gothic Demi Cond',
#  'Trebuchet MS',
#  'Comic Sans MS',
#  'Century Schoolbook',
#  'HoloLens MDL2 Assets',
#  'Lucida Bright',
#  'Lucida Sans',
#  'Showcard Gothic',
#  'Gadugi',
#  'Segoe UI',
#  'Segoe UI',
#  'Century Gothic',
#  'Bookman Old Style',
#  'Bodoni MT',
#  'Marlett',
#  'Magneto',
#  'Harrington',
#  'Century Schoolbook',
#  'Goudy Stout',
#  'Sitka Small',
#  'Candara',
#  'Microsoft PhagsPa',
#  'Segoe UI',
#  'Candara',
#  'Microsoft YaHei',
#  'Franklin Gothic Heavy',
#  'Bodoni MT',
#  'Century Schoolbook',
#  'Arial',
#  'Century Gothic',
#  'Nirmala UI',
#  'Lucida Fax',
#  'Rage Italic',
#  'Corbel',
#  'Javanese Text',
#  'SimSun-ExtB',
#  'Consolas',
#  'Courier New',
#  'HYGungSo-Bold',
#  'Microsoft New Tai Lue',
#  'Goudy Old Style',
#  'Imprint MT Shadow',
#  'Tempus Sans ITC',
#  'Bodoni MT',
#  'Berlin Sans FB',
#  'Lucida Fax',
#  'Forte',
#  'Bookman Old Style',
#  'Garamond',
#  'Arial',
#  'Californian FB',
#  'Perpetua',
#  'Cooper Black',
#  'Consolas',
#  'Calisto MT',
#  'SimSun',
#  'Jokerman',
#  'Niagara Engraved',
#  'Verdana',
#  'Georgia',
#  'Goudy Old Style',
#  'Centaur',
#  'High Tower Text',
#  'Maiandra GD',
#  'Dubai',
#  'Harrington',
#  'Rockwell Condensed',
#  'Courier New',
#  'Kunstler Script',
#  'HCR Batang',
#  'Ami R',
#  'Monotype Corsiva',
#  'HYMyeongJo-Extra',
#  'Tahoma',
#  'Lucida Fax',
#  'Yu Gothic',
#  'Viner Hand ITC',
#  'Malgun Gothic',
#  'Perpetua',
#  'Corbel',
#  'Franklin Gothic Book',
#  'HCR Batang Ext',
#  'Verdana',
#  'Copperplate Gothic Light',
#  'Bodoni MT',
#  'MS Gothic',
#  'Bookman Old Style',
#  'Gloucester MT Extra Condensed',
#  'Bodoni MT',
#  'Gill Sans MT Ext Condensed Bold',
#  'Yu Gothic',
#  'Bodoni MT',
#  'Microsoft Sans Serif',
#  'Gill Sans MT',
#  'Franklin Gothic Book',
#  'Times New Roman',
#  'Curlz MT',
#  'Tw Cen MT',
#  'Magneto',
#  'Segoe UI Symbol',
#  'Arial Rounded MT Bold',
#  'Century Schoolbook',
#  'Lucida Sans Typewriter',
#  'MT Extra',
#  'Tw Cen MT Condensed Extra Bold',
#  'Segoe UI',
#  'Tw Cen MT',
#  'Trebuchet MS',
#  'Franklin Gothic Medium Cond',
#  'MS Reference Sans Serif',
#  'Verdana',
#  'MS Gothic',
#  'Palace Script MT',
#  'Corbel',
#  'Lucida Sans',
#  'Segoe Script',
#  'Segoe UI',
#  'Baskerville Old Face',
#  'Comic Sans MS',
#  'Garamond',
#  'Lucida Fax',
#  'Parchment',
#  'MS Reference Specialty',
#  'MV Boli',
#  'Bradley Hand ITC',
#  'Candara',
#  'Lucida Sans Typewriter',
#  'Microsoft Yi Baiti',
#  'Kunstler Script',
#  'Book Antiqua',
#  'Arial',
#  'Leelawadee UI',
#  'Freestyle Script',
#  'Maiandra GD',
#  'Lucida Fax',
#  'Nirmala UI',
#  'Poor Richard',
#  'Lucida Console',
#  'Sylfaen',
#  'Verdana',
#  'MS Reference Specialty',
#  'Eras Demi ITC',
#  'Lucida Bright',
#  'Palatino Linotype',
#  'Consolas',
#  'Goudy Old Style',
#  'Rockwell',
#  'Calibri',
#  'Perpetua Titling MT',
#  'Nirmala UI',
#  'Calibri',
#  'Myanmar Text',
#  'Broadway',
#  'Berlin Sans FB Demi',
#  'Arial',
#  'Franklin Gothic Demi',
#  'Constantia',
#  'Lucida Bright',
#  'Gulim',
#  'Parchment',
#  'Comic Sans MS',
#  'Corbel',
#  'Candara',
#  'Centaur',
#  'Georgia',
#  'Leelawadee UI',
#  'Arial',
#  'Book Antiqua',
#  'Yu Gothic',
#  'Vladimir Script',
#  'Haan Wing2',
#  'Segoe UI',
#  'Bell MT',
#  'Franklin Gothic Medium',
#  'Playbill',
#  'Segoe Script',
#  'Segoe UI',
#  'Comic Sans MS',
#  'Sitka Small',
#  'Hancom Gothic',
#  'HCR Batang ExtB',
#  'HYPMokGak-Bold',
#  'High Tower Text',
#  'Candara',
#  'Rockwell Extra Bold',
#  'Mongolian Baiti',
#  'Consolas',
#  'Viner Hand ITC',
#  'Arial',
#  'Microsoft New Tai Lue',
#  'Lucida Fax',
#  'Tw Cen MT Condensed',
#  'Palatino Linotype',
#  'Times New Roman',
#  'Corbel',
#  'Niagara Solid',
#  'Courier New',
#  'Times New Roman',
#  'Calibri',
#  'Comic Sans MS',
#  'Showcard Gothic',
#  'Juice ITC',
#  'Segoe UI Historic',
#  'Book Antiqua',
#  'Courier New',
#  'Agency FB',
#  'Onyx',
#  'Nanum Pen Script',
#  'Calisto MT',
#  'Kristen ITC',
#  'Javanese Text',
#  'Californian FB',
#  'Gloucester MT Extra Condensed',
#  'Bodoni MT',
#  'Agency FB',
#  'Tahoma',
#  'HYSinMyeongJo-Medium',
#  'Goudy Stout',
#  'Webdings',
#  'Arial',
#  'Trebuchet MS',
#  'Arial Rounded MT Bold',
#  'Haettenschweiler',
#  'Bookman Old Style',
#  'Nirmala UI',
#  'Perpetua',
#  'Gill Sans Ultra Bold',
#  'Microsoft Himalaya',
#  'Consolas',
#  'Papyrus',
#  'Rockwell',
#  'Cambria',
#  'Calisto MT',
#  'Lucida Fax',
#  'Lucida Calligraphy',
#  'Segoe Print',
#  'Ebrima',
#  'Microsoft YaHei',
#  'Sitka Small',
#  'New Gulim',
#  'Berlin Sans FB',
#  'Calisto MT',
#  'Ravie',
#  'Ink Free',
#  'Rockwell Condensed',
#  'Malgun Gothic',
#  'Palace Script MT',
#  'Eras Light ITC',
#  'Lucida Sans',
#  'Bookman Old Style',
#  'Candara',
#  'Segoe UI',
#  'Cambria']

# %%
plt.plot(x,y)
plt.title("꺾은선 그래프")
# Out:
# Text(0.5, 1.0, '꺾은선 그래프')

# %%
plt.plot([-1, 0, 1], [-5, -1., 2])
