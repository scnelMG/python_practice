# %%
import pandas as pd
import numpy as np
from sklearn.naive_bayes import GaussianNB
from google.colab import drive
drive.mount('/content/gdriv')
# Out:
# Drive already mounted at /content/gdriv; to attempt to forcibly remount, call drive.mount("/content/gdriv", force_remount=True).

# %%
import os
data_path = "/content/gdriv/My Drive/Colab Notebooks/data" 
dt = pd.read_csv(data_path + '/titanic.csv')
pred_dt = pd.read_csv(data_path + '/titanic_term_without_y.csv')

# %%
dt
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  alone
# 0           0       3    male  22.0      1      0   7.2500        S  False
# 1           1       1  female  38.0      1      0  71.2833        C  False
# 2           1       3  female  26.0      0      0   7.9250        S   True
# 3           1       1  female  35.0      1      0  53.1000        S  False
# 4           0       3    male  35.0      0      0   8.0500        S   True
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 650         1       3    male  27.0      0      0   8.6625        S   True
# 651         0       1    male  38.0      0      0   0.0000        S   True
# 652         1       3  female  27.0      0      1  12.4750        S  False
# 653         0       3    male   2.0      4      1  39.6875        S  False
# 654         1       2    male   1.0      0      2  37.0042        C  False
#
# [655 rows x 9 columns]

# %%
pred_dt
# Out:
#     pclass     sex   age  sibsp  parch      fare embarked  alone
# 0        3  female  15.0      1      0   14.4542        C  False
# 1        3    male  23.0      0      0    7.8542        S   True
# 2        3    male  18.0      0      0    8.3000        S   True
# 3        1  female  39.0      1      1   83.1583        C  False
# 4        3    male  21.0      0      0    8.6625        S   True
# 5        3    male  32.0      0      0   56.4958        S   True
# 6        3    male  20.0      0      0    7.9250        S   True
# 7        2    male  16.0      0      0   10.5000        S   True
# 8        1  female  30.0      0      0   31.0000        C   True
# 9        3    male  34.5      0      0    6.4375        C   True
# 10       3    male  17.0      0      0    8.6625        S   True
# 11       3    male  42.0      0      0    7.5500        S   True
# 12       3    male  35.0      0      0    7.8958        C   True
# ...

# %%
t_dt = pd.concat([dt, pred_dt])

# %%
t_dt
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked  alone
# 0        0.0       3    male  22.0      1      0   7.2500        S  False
# 1        1.0       1  female  38.0      1      0  71.2833        C  False
# 2        1.0       3  female  26.0      0      0   7.9250        S   True
# 3        1.0       1  female  35.0      1      0  53.1000        S  False
# 4        0.0       3    male  35.0      0      0   8.0500        S   True
# ..       ...     ...     ...   ...    ...    ...      ...      ...    ...
# 45       NaN       3  female  39.0      0      5  29.1250        Q  False
# 46       NaN       2    male  27.0      0      0  13.0000        S   True
# 47       NaN       1  female  19.0      0      0  30.0000        S   True
# 48       NaN       1    male  26.0      0      0  30.0000        C   True
# 49       NaN       3    male  32.0      0      0   7.7500        Q   True
#
# [705 rows x 9 columns]

# %%
t_dt.dtypes
# Out:
# survived    float64
# pclass        int64
# sex          object
# age         float64
# sibsp         int64
# parch         int64
# fare        float64
# embarked     object
# alone          bool
# dtype: object

# %%
t_dt['alone'] = pd.Categorical(t_dt['alone'])

# %%
t_dt = pd.get_dummies(t_dt,prefix_sep='_',drop_first=True)
t_dt
# Out:
#     survived  pclass   age  sibsp  ...  sex_male  embarked_Q  embarked_S  alone_True
# 0        0.0       3  22.0      1  ...         1           0           1           0
# 1        1.0       1  38.0      1  ...         0           0           0           0
# 2        1.0       3  26.0      0  ...         0           0           1           1
# 3        1.0       1  35.0      1  ...         0           0           1           0
# 4        0.0       3  35.0      0  ...         1           0           1           1
# ..       ...     ...   ...    ...  ...       ...         ...         ...         ...
# 45       NaN       3  39.0      0  ...         0           1           0           0
# 46       NaN       2  27.0      0  ...         1           0           1           1
# 47       NaN       1  19.0      0  ...         0           0           1           1
# 48       NaN       1  26.0      0  ...         1           0           0           1
# ...

# %%
dt = t_dt.iloc[:len(dt),:]

# %%
pred_dt = t_dt.iloc[len(dt):,:]

# %%
dt.shape
# Out:
# (655, 10)

# %%
pred_dt.shape
# Out:
# (50, 10)

# %%
pred_dt
# Out:
#     survived  pclass   age  sibsp  ...  sex_male  embarked_Q  embarked_S  alone_True
# 0        NaN       3  15.0      1  ...         0           0           0           0
# 1        NaN       3  23.0      0  ...         1           0           1           1
# 2        NaN       3  18.0      0  ...         1           0           1           1
# 3        NaN       1  39.0      1  ...         0           0           0           0
# 4        NaN       3  21.0      0  ...         1           0           1           1
# 5        NaN       3  32.0      0  ...         1           0           1           1
# 6        NaN       3  20.0      0  ...         1           0           1           1
# 7        NaN       2  16.0      0  ...         1           0           1           1
# 8        NaN       1  30.0      0  ...         0           0           0           1
# 9        NaN       3  34.5      0  ...         1           0           0           1
# ...

# %%
trainx = dt.iloc[:,1:].to_numpy()
trainy = dt.iloc[:,0].to_numpy()
testx = pred_dt.iloc[:,1:].to_numpy()
testy = pred_dt.iloc[:,0].to_numpy()

# %%
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import confusion_matrix

# %%
model = GaussianNB()

# %%
model.fit(trainx,trainy)
# Out:
# GaussianNB(priors=None, var_smoothing=1e-09)

# %%
 train_pred = model.predict(trainx)

# %%
m = confusion_matrix(trainy, train_pred)
print(m)
np.sum(np.diag(m))/len(trainx)
# Out:
# [[331  63]
#  [ 81 180]]
# 0.7801526717557252

# %%
test_pred = model.predict(testx)

# %%
result_survived = pd.DataFrame(test_pred)

# %%
result = pd.concat([pred_dt,result_survived],axis=1)

# %%
result= result.iloc[:,1:]

# %%
result
# Out:
#     pclass   age  sibsp  parch  ...  embarked_Q  embarked_S  alone_True    0
# 0        3  15.0      1      0  ...           0           0           0  1.0
# 1        3  23.0      0      0  ...           0           1           1  0.0
# 2        3  18.0      0      0  ...           0           1           1  0.0
# 3        1  39.0      1      1  ...           0           0           0  1.0
# 4        3  21.0      0      0  ...           0           1           1  0.0
# 5        3  32.0      0      0  ...           0           1           1  0.0
# 6        3  20.0      0      0  ...           0           1           1  0.0
# 7        2  16.0      0      0  ...           0           1           1  0.0
# 8        1  30.0      0      0  ...           0           0           1  1.0
# 9        3  34.5      0      0  ...           0           0           1  0.0
# 10       3  17.0      0      0  ...           0           1           1  0.0
# ...

# %%
result.rename(columns = {0 : "pred_survived"}, inplace = True)

# %%
result
# Out:
#     pclass   age  sibsp  ...  embarked_S  alone_True  pred_survived
# 0        3  15.0      1  ...           0           0            1.0
# 1        3  23.0      0  ...           1           1            0.0
# 2        3  18.0      0  ...           1           1            0.0
# 3        1  39.0      1  ...           0           0            1.0
# 4        3  21.0      0  ...           1           1            0.0
# 5        3  32.0      0  ...           1           1            0.0
# 6        3  20.0      0  ...           1           1            0.0
# 7        2  16.0      0  ...           1           1            0.0
# 8        1  30.0      0  ...           0           1            1.0
# 9        3  34.5      0  ...           0           1            0.0
# 10       3  17.0      0  ...           1           1            0.0
# 11       3  42.0      0  ...           1           1            0.0
# 12       3  35.0      0  ...           0           1            0.0
# ...
