# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/gdriv')
# Out:
# Mounted at /content/gdriv

# %%
# !ls "/content/gdriv/My Drive/Colab Notebooks/data"
# Out:
# archive.zip  datasets_19_420_Iris.csv

# %%
import os
data_path = "/content/gdriv/My Drive/Colab Notebooks/data" 
data_name = os.listdir(data_path)
print(data_name)
iris = pd.read_csv(data_path + '/' + data_name[0])
iris.head()
# Out:
# ['datasets_19_420_Iris.csv', 'archive.zip']
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris
# Out:
#       Id  SepalLengthCm  ...  PetalWidthCm         Species
# 0      1            5.1  ...           0.2     Iris-setosa
# 1      2            4.9  ...           0.2     Iris-setosa
# 2      3            4.7  ...           0.2     Iris-setosa
# 3      4            4.6  ...           0.2     Iris-setosa
# 4      5            5.0  ...           0.2     Iris-setosa
# ..   ...            ...  ...           ...             ...
# 145  146            6.7  ...           2.3  Iris-virginica
# 146  147            6.3  ...           1.9  Iris-virginica
# 147  148            6.5  ...           2.0  Iris-virginica
# 148  149            6.2  ...           2.3  Iris-virginica
# 149  150            5.9  ...           1.8  Iris-virginica
#
# [150 rows x 6 columns]

# %% [markdown]
# **INPUT**

# %%
iris.loc[:,['Species','SepalLengthCm']]
# Out:
#             Species  SepalLengthCm
# 0       Iris-setosa            5.1
# 1       Iris-setosa            4.9
# 2       Iris-setosa            4.7
# 3       Iris-setosa            4.6
# 4       Iris-setosa            5.0
# ..              ...            ...
# 145  Iris-virginica            6.7
# 146  Iris-virginica            6.3
# 147  Iris-virginica            6.5
# 148  Iris-virginica            6.2
# 149  Iris-virginica            5.9
#
# [150 rows x 2 columns]

# %%
input = iris.loc[:,['Species','SepalLengthCm']]
print(input)
# Out:
#             Species  SepalLengthCm
# 0       Iris-setosa            5.1
# 1       Iris-setosa            4.9
# 2       Iris-setosa            4.7
# 3       Iris-setosa            4.6
# 4       Iris-setosa            5.0
# ..              ...            ...
# 145  Iris-virginica            6.7
# 146  Iris-virginica            6.3
# 147  Iris-virginica            6.5
# 148  Iris-virginica            6.2
# 149  Iris-virginica            5.9
#
# [150 rows x 2 columns]

# %%
print(iris['Species'].value_counts())
# Out:
# Iris-virginica     50
# Iris-setosa        50
# Iris-versicolor    50
# Name: Species, dtype: int64

# %% [markdown]
# **SPLIT by Species**

# %%
split_1 = iris.loc[iris['Species']=='Iris-setosa',['Species','SepalLengthCm']]

# %%
split_1
# Out:
#         Species  SepalLengthCm
# 0   Iris-setosa            5.1
# 1   Iris-setosa            4.9
# 2   Iris-setosa            4.7
# 3   Iris-setosa            4.6
# 4   Iris-setosa            5.0
# 5   Iris-setosa            5.4
# 6   Iris-setosa            4.6
# 7   Iris-setosa            5.0
# 8   Iris-setosa            4.4
# 9   Iris-setosa            4.9
# 10  Iris-setosa            5.4
# 11  Iris-setosa            4.8
# 12  Iris-setosa            4.8
# 13  Iris-setosa            4.3
# 14  Iris-setosa            5.8
# 15  Iris-setosa            5.7
# 16  Iris-setosa            5.4
# 17  Iris-setosa            5.1
# 18  Iris-setosa            5.7
# 19  Iris-setosa            5.1
# 20  Iris-setosa            5.4
# 21  Iris-setosa            5.1
# 22  Iris-setosa            4.6
# 23  Iris-setosa            5.1
# 24  Iris-setosa            4.8
# 25  Iris-setosa            5.0
# 26  Iris-setosa            5.0
# 27  Iris-setosa            5.2
# 28  Iris-setosa            5.2
# ...

# %%
split_2 = iris.loc[iris['Species']=='Iris-versicolor',['Species','SepalLengthCm']]

# %%
split_2
# Out:
#             Species  SepalLengthCm
# 50  Iris-versicolor            7.0
# 51  Iris-versicolor            6.4
# 52  Iris-versicolor            6.9
# 53  Iris-versicolor            5.5
# 54  Iris-versicolor            6.5
# 55  Iris-versicolor            5.7
# 56  Iris-versicolor            6.3
# 57  Iris-versicolor            4.9
# 58  Iris-versicolor            6.6
# 59  Iris-versicolor            5.2
# 60  Iris-versicolor            5.0
# 61  Iris-versicolor            5.9
# 62  Iris-versicolor            6.0
# 63  Iris-versicolor            6.1
# 64  Iris-versicolor            5.6
# 65  Iris-versicolor            6.7
# 66  Iris-versicolor            5.6
# 67  Iris-versicolor            5.8
# 68  Iris-versicolor            6.2
# 69  Iris-versicolor            5.6
# 70  Iris-versicolor            5.9
# 71  Iris-versicolor            6.1
# 72  Iris-versicolor            6.3
# 73  Iris-versicolor            6.1
# 74  Iris-versicolor            6.4
# 75  Iris-versicolor            6.6
# ...

# %%
split_2 = split_2.reset_index(drop=True)

# %%
split_3 = iris.loc[iris['Species']=='Iris-virginica',['Species','SepalLengthCm']]

# %%
split_3
# Out:
#             Species  SepalLengthCm
# 100  Iris-virginica            6.3
# 101  Iris-virginica            5.8
# 102  Iris-virginica            7.1
# 103  Iris-virginica            6.3
# 104  Iris-virginica            6.5
# 105  Iris-virginica            7.6
# 106  Iris-virginica            4.9
# 107  Iris-virginica            7.3
# 108  Iris-virginica            6.7
# 109  Iris-virginica            7.2
# 110  Iris-virginica            6.5
# 111  Iris-virginica            6.4
# 112  Iris-virginica            6.8
# 113  Iris-virginica            5.7
# 114  Iris-virginica            5.8
# 115  Iris-virginica            6.4
# 116  Iris-virginica            6.5
# 117  Iris-virginica            7.7
# 118  Iris-virginica            7.7
# 119  Iris-virginica            6.0
# 120  Iris-virginica            6.9
# 121  Iris-virginica            5.6
# 122  Iris-virginica            7.7
# 123  Iris-virginica            6.3
# 124  Iris-virginica            6.7
# 125  Iris-virginica            7.2
# ...

# %%
split_3 = split_3.reset_index(drop=True)

# %% [markdown]
# **APPLY_Sum**

# %%
split_1.iloc[:,1:2].apply(lambda x:x.sum())
# Out:
# SepalLengthCm    250.3
# dtype: float64

# %%
sum1 = split_1.iloc[:,1:2].apply(lambda x:x.sum())

# %%
split_1.loc[50,0:2] = 'Iris-setosa',sum1
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Slicing a positional slice with .loc is not supported, and will raise TypeError in a future version.  Use .loc with labels or .iloc with positions instead.
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %%
split_1.rename(index = {50 : 'Sum'},inplace = True)

# %%
split_1
# Out:
#          Species  SepalLengthCm
# 0    Iris-setosa            5.1
# 1    Iris-setosa            4.9
# 2    Iris-setosa            4.7
# 3    Iris-setosa            4.6
# 4    Iris-setosa            5.0
# 5    Iris-setosa            5.4
# 6    Iris-setosa            4.6
# 7    Iris-setosa            5.0
# 8    Iris-setosa            4.4
# 9    Iris-setosa            4.9
# 10   Iris-setosa            5.4
# 11   Iris-setosa            4.8
# 12   Iris-setosa            4.8
# 13   Iris-setosa            4.3
# 14   Iris-setosa            5.8
# 15   Iris-setosa            5.7
# 16   Iris-setosa            5.4
# 17   Iris-setosa            5.1
# 18   Iris-setosa            5.7
# 19   Iris-setosa            5.1
# 20   Iris-setosa            5.4
# 21   Iris-setosa            5.1
# 22   Iris-setosa            4.6
# 23   Iris-setosa            5.1
# 24   Iris-setosa            4.8
# 25   Iris-setosa            5.0
# 26   Iris-setosa            5.0
# 27   Iris-setosa            5.2
# ...

# %%
apply_1 = split_1.iloc[50:51,0:2]

# %%
apply_1 = apply_1.reset_index(drop=True)

# %%
apply_1
# Out:
#        Species  SepalLengthCm
# 0  Iris-setosa          250.3

# %%
split_2.iloc[:,1:2].apply(lambda x:x.sum())
# Out:
# SepalLengthCm    296.8
# dtype: float64

# %%
sum2 = split_2.iloc[:,1:2].apply(lambda x:x.sum())

# %%
split_2.loc[50,0:2] = 'Iris-versicolor  ',sum2
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Slicing a positional slice with .loc is not supported, and will raise TypeError in a future version.  Use .loc with labels or .iloc with positions instead.
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %%
split_2.rename(index = {50 : 'Sum'},inplace = True)

# %%
split_2
# Out:
#                Species  SepalLengthCm
# 0      Iris-versicolor            7.0
# 1      Iris-versicolor            6.4
# 2      Iris-versicolor            6.9
# 3      Iris-versicolor            5.5
# 4      Iris-versicolor            6.5
# 5      Iris-versicolor            5.7
# 6      Iris-versicolor            6.3
# 7      Iris-versicolor            4.9
# 8      Iris-versicolor            6.6
# 9      Iris-versicolor            5.2
# 10     Iris-versicolor            5.0
# 11     Iris-versicolor            5.9
# 12     Iris-versicolor            6.0
# 13     Iris-versicolor            6.1
# 14     Iris-versicolor            5.6
# 15     Iris-versicolor            6.7
# 16     Iris-versicolor            5.6
# 17     Iris-versicolor            5.8
# 18     Iris-versicolor            6.2
# 19     Iris-versicolor            5.6
# 20     Iris-versicolor            5.9
# 21     Iris-versicolor            6.1
# 22     Iris-versicolor            6.3
# 23     Iris-versicolor            6.1
# ...

# %%
apply_2 = split_2.iloc[50:51,0:2]

# %%
apply_2 = apply_2.reset_index(drop=True)

# %%
apply_2
# Out:
#              Species  SepalLengthCm
# 0  Iris-versicolor            296.8

# %%
split_3.iloc[:,1:2].apply(lambda x:x.sum())
# Out:
# SepalLengthCm    329.4
# dtype: float64

# %%
sum3 = split_3.iloc[:,1:2].apply(lambda x:x.sum())

# %%
split_3.loc[50,0:2] = 'Iris-virginica',sum3
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Slicing a positional slice with .loc is not supported, and will raise TypeError in a future version.  Use .loc with labels or .iloc with positions instead.
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %%
split_3.rename(index = {50 : 'Sum'},inplace = True)

# %%
split_3
# Out:
#             Species  SepalLengthCm
# 0    Iris-virginica            6.3
# 1    Iris-virginica            5.8
# 2    Iris-virginica            7.1
# 3    Iris-virginica            6.3
# 4    Iris-virginica            6.5
# 5    Iris-virginica            7.6
# 6    Iris-virginica            4.9
# 7    Iris-virginica            7.3
# 8    Iris-virginica            6.7
# 9    Iris-virginica            7.2
# 10   Iris-virginica            6.5
# 11   Iris-virginica            6.4
# 12   Iris-virginica            6.8
# 13   Iris-virginica            5.7
# 14   Iris-virginica            5.8
# 15   Iris-virginica            6.4
# 16   Iris-virginica            6.5
# 17   Iris-virginica            7.7
# 18   Iris-virginica            7.7
# 19   Iris-virginica            6.0
# 20   Iris-virginica            6.9
# 21   Iris-virginica            5.6
# 22   Iris-virginica            7.7
# 23   Iris-virginica            6.3
# 24   Iris-virginica            6.7
# 25   Iris-virginica            7.2
# ...

# %%
apply_3 = split_3.iloc[50:51,0:2]

# %%
apply_3 = apply_3.reset_index(drop=True)

# %%
apply_3
# Out:
#           Species  SepalLengthCm
# 0  Iris-virginica          329.4

# %% [markdown]
# **conbine**

# %%
merge = pd.concat([apply_1, apply_2, apply_3],axis=0)

# %%
merge = merge.reset_index(drop=True)

# %%
merge
# Out:
#              Species  SepalLengthCm
# 0        Iris-setosa          250.3
# 1  Iris-versicolor            296.8
# 2     Iris-virginica          329.4
