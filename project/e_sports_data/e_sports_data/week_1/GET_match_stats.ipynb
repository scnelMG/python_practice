# %%
import pandas as pd
import numpy as np
import requests

# %%
# Riot Developer Portal에서 받은 API KEY입니다.
# 해당 값을 포함한 모든 종류의 KEY는 코드에 직접적으로 노출되지 않도록 하는 것이 좋습니다.
api_key = 'RGAPI-80e3307a-8620-40dc-bcef-b78a866b75aa'

# 본인 소환사명입니다.
summoner_name = 'midplayerorafk'

# %%
# SUMMONER-V4 API URL
requesturl = 'https://kr.api.riotgames.com/lol/summoner/v4/summoners/by-name/'+summoner_name+\
'?api_key='+api_key

# %%
r = requests.get(requesturl)

# %%
# 불러온 데이터 확인
r.json()
# Out:
# {'accountId': 'ZcdmNxaL3lnJZcxjmA6VHO7MN5-37cYw7L0-DgoqJsjpDIg',
#  'id': 'd2WlC7yRaw7XBT3aY61bJVX0vH1PTQu1CC_UbqnXezGAvvI',
#  'name': 'midplayer or AFK',
#  'profileIconId': 4863,
#  'puuid': 'ZRQMRm9bJeet28u08d7A0CiShrV4hJMljeeewRsxGE-5mOm-ElPIQlplK6kkMf-dM-mWAMcA2ywlzQ',
#  'revisionDate': 1634011341000,
#  'summonerLevel': 169}

# %%
# 본인 puuid입니다.
summoner_puuid = r.json()['puuid']

# %%
summoner_puuid
# Out:
# 'ZRQMRm9bJeet28u08d7A0CiShrV4hJMljeeewRsxGE-5mOm-ElPIQlplK6kkMf-dM-mWAMcA2ywlzQ'

# %%
# MATCH-V5 API URL
requesturl = 'https://asia.api.riotgames.com/lol/match/v5/matches/by-puuid/'+summoner_puuid+\
'/ids?start=0&count=100&api_key='+api_key

# %%
r = requests.get(requesturl)

# %%
# 불러온 데이터 확인
r.json()
# Out:
# ['KR_5507541819',
#  'KR_5507469774',
#  'KR_5507417922',
#  'KR_5506990572',
#  'KR_5506959118',
#  'KR_5506978025',
#  'KR_5506889686',
#  'KR_5506918758',
#  'KR_5505993936',
#  'KR_5505947266',
#  'KR_5504648486',
#  'KR_5503204743',
#  'KR_5502937995',
#  'KR_5482069284',
#  'KR_5482100657',
#  'KR_5482068613',
#  'KR_5482058245',
#  'KR_5482058001',
#  'KR_5482028072',
#  'KR_5469854606',
#  'KR_5469812211',
#  'KR_5469699850',
#  'KR_5464062998',
#  'KR_5463869236',
#  'KR_5463836202',
#  'KR_5457760082',
#  'KR_5452808998',
#  'KR_5452747487',
#  'KR_5452793372',
#  'KR_5452698497',
#  'KR_5439654128',
#  'KR_5439611313',
#  'KR_5439467495',
#  'KR_5434604410',
#  'KR_5434621898',
#  'KR_5434588684',
#  'KR_5434585636',
#  'KR_5425061942',
#  'KR_5423291286',
#  'KR_5423109935',
#  'KR_5418791148',
#  'KR_5418668424',
#  'KR_5418695763',
#  'KR_5418634762',
#  'KR_5417310543',
#  'KR_5416999188',
#  'KR_5410978939',
#  'KR_5410918929',
#  'KR_5410916087',
#  'KR_5410963547',
#  'KR_5404612925',
#  'KR_5404524650',
#  'KR_5404551967',
#  'KR_5404475794',
#  'KR_5400506815',
#  'KR_5400561855',
#  'KR_5400448738',
#  'KR_5400455630',
#  'KR_5400384457',
#  'KR_5400359462',
#  'KR_5400337218',
#  'KR_5398853152',
#  'KR_5398800470',
#  'KR_5398697768',
#  'KR_5398704496',
#  'KR_5395680734',
#  'KR_5395585597',
#  'KR_5395581579',
#  'KR_5393714140',
#  'KR_5393750522',
#  'KR_5393526298',
#  'KR_5381394649',
#  'KR_5374210290',
#  'KR_5374185485',
#  'KR_5374112744',
#  'KR_5374100508',
#  'KR_5372845470',
#  'KR_5369307960',
#  'KR_5369227316',
#  'KR_5367838607',
#  'KR_5366364922',
#  'KR_5366269095',
#  'KR_5365624444',
#  'KR_5365611359',
#  'KR_5361795019',
#  'KR_5361761911',
#  'KR_5361700106',
#  'KR_5361103314',
#  'KR_5360839592',
#  'KR_5360896421',
#  'KR_5360179567',
#  'KR_5360176594',
#  'KR_5360122368',
#  'KR_5360089421',
#  'KR_5357743883',
#  'KR_5357699093',
#  'KR_5357655815',
#  'KR_5355742651',
#  'KR_5355697266',
#  'KR_5351869422']

# %%
# 데이터 가져올 matchId입니다.
for i in range(0,len(r.json())):
  matchId = r.json()[i]
  requesturl = 'https://asia.api.riotgames.com/lol/match/v5/matches/'+matchId\
+'?api_key='+api_key
  r2 = requests.get(requesturl)
  df = pd.DataFrame(r2.json()['info']['participants'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-111-0c916399b8d1> in <module>()
#       4   requesturl = 'https://asia.api.riotgames.com/lol/match/v5/matches/'+matchId+'?api_key='+api_key
#       5   r2 = requests.get(requesturl)
# ----> 6   df = pd.DataFrame(r2.json()['info']['participants'])
#
# KeyError: 'info'

# %%
# Out:
# <bound method Response.json of <Response [429]>>

# %%
# MATCH-V5 API URL
requesturl = 'https://asia.api.riotgames.com/lol/match/v5/matches/'+matchId\
+'?api_key='+api_key

# %%
r = requests.get(requesturl)

# %%
# 불러온 데이터 확인
r.json()
# Out:
# {'info': {'gameCreation': 1634033451000,
#   'gameDuration': 990,
#   'gameEndTimestamp': 1634034467981,
#   'gameId': 5507417922,
#   'gameMode': 'URF',
#   'gameName': 'teambuilder-match-5507417922',
#   'gameStartTimestamp': 1634033477121,
#   'gameType': 'MATCHED_GAME',
#   'gameVersion': '11.20.400.7328',
#   'mapId': 11,
#   'participants': [{'assists': 4,
#     'baronKills': 0,
#     'bountyLevel': 0,
#     'champExperience': 22496,
#     'champLevel': 20,
#     'championId': 75,
#     'championName': 'Nasus',
#     'championTransform': 0,
#     'consumablesPurchased': 4,
#     'damageDealtToBuildings': 5579,
#     'damageDealtToObjectives': 5630,
#     'damageDealtToTurrets': 5579,
#     'damageSelfMitigated': 45595,
#     'deaths': 8,
#     'detectorWardsPlaced': 0,
#     'doubleKills': 1,
#     'dragonKills': 0,
#     'firstBloodAssist': False,
#     'firstBloodKill': True,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'goldEarned': 15765,
#     'goldSpent': 14900,
#     'individualPosition': 'Invalid',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 0,
#     'inhibitorsLost': 4,
#     'item0': 1001,
#     'item1': 3181,
#     'item2': 6632,
#     'item3': 3075,
#     'item4': 3065,
#     'item5': 3001,
#     'item6': 3340,
#     'itemsPurchased': 23,
#     'killingSprees': 2,
#     'kills': 10,
#     'lane': 'NONE',
#     'largestCriticalStrike': 22,
#     'largestKillingSpree': 5,
#     'largestMultiKill': 2,
#     'longestTimeSpentLiving': 189,
#     'magicDamageDealt': 11483,
#     'magicDamageDealtToChampions': 3990,
#     'magicDamageTaken': 16476,
#     'neutralMinionsKilled': 24,
#     'nexusKills': 0,
#     'nexusLost': 1,
#     'nexusTakedowns': 0,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'participantId': 1,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5001, 'flex': 5008, 'offense': 5008},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8230, 'var1': 15, 'var2': 0, 'var3': 0},
#         {'perk': 8275, 'var1': 14, 'var2': 0, 'var3': 0},
#         {'perk': 8234, 'var1': 7977, 'var2': 0, 'var3': 0},
#         {'perk': 8237, 'var1': 422, 'var2': 0, 'var3': 0}],
#        'style': 8200},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8135, 'var1': 3904, 'var2': 5, 'var3': 0},
#         {'perk': 8126, 'var1': 683, 'var2': 0, 'var3': 0}],
#        'style': 8100}]},
#     'physicalDamageDealt': 108443,
#     'physicalDamageDealtToChampions': 19362,
#     'physicalDamageTaken': 19344,
#     'profileIcon': 4087,
#     'puuid': 'LX7j68CtwzgVjJ17lZKmCyHTp8GKGjlGY5pjOYdWtCU3ag9IydXCG7U09cxy4ynZxKV3DXzgMHCr_A',
#     'quadraKills': 0,
#     'riotIdName': '',
#     'riotIdTagline': '',
#     'role': 'SUPPORT',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 202,
#     'spell2Casts': 24,
#     'spell3Casts': 37,
#     'spell4Casts': 11,
#     'summoner1Casts': 8,
#     'summoner1Id': 6,
#     'summoner2Casts': 6,
#     'summoner2Id': 4,
#     'summonerId': 'n2N8m_cTFdkSbwkCBtmu8or23ojrMp9Cy2X1pIw7D31H3mI',
#     'summonerLevel': 210,
#     'summonerName': '행동대장 김예진',
#     'teamEarlySurrendered': False,
#     'teamId': 100,
#     'teamPosition': '',
#     'timeCCingOthers': 12,
#     'timePlayed': 990,
#     'totalDamageDealt': 121807,
#     'totalDamageDealtToChampions': 24363,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 44471,
#     'totalHeal': 3174,
#     'totalHealsOnTeammates': 0,
#     'totalMinionsKilled': 100,
#     'totalTimeCCDealt': 102,
#     'totalTimeSpentDead': 217,
#     'totalUnitsHealed': 1,
#     'tripleKills': 0,
#     'trueDamageDealt': 1880,
#     'trueDamageDealtToChampions': 1010,
#     'trueDamageTaken': 8651,
#     'turretKills': 1,
#     'turretTakedowns': 1,
#     'turretsLost': 11,
#     'unrealKills': 0,
#     'visionScore': 4,
#     'visionWardsBoughtInGame': 0,
#     'wardsKilled': 1,
#     'wardsPlaced': 2,
#     'win': False},
#    {'assists': 7,
#     'baronKills': 0,
#     'bountyLevel': 0,
#     'champExperience': 19135,
#     'champLevel': 18,
#     'championId': 51,
#     'championName': 'Caitlyn',
#     'championTransform': 0,
#     'consumablesPurchased': 0,
#     'damageDealtToBuildings': 3443,
#     'damageDealtToObjectives': 7306,
#     'damageDealtToTurrets': 3443,
#     'damageSelfMitigated': 9345,
#     'deaths': 9,
#     'detectorWardsPlaced': 0,
#     'doubleKills': 0,
#     'dragonKills': 0,
#     'firstBloodAssist': True,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'goldEarned': 13278,
#     'goldSpent': 12950,
#     'individualPosition': 'Invalid',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 0,
#     'inhibitorsLost': 4,
#     'item0': 6691,
#     'item1': 3814,
#     'item2': 6695,
#     'item3': 1001,
#     'item4': 6676,
#     'item5': 3123,
#     'item6': 3363,
#     'itemsPurchased': 26,
#     'killingSprees': 1,
#     'kills': 6,
#     'lane': 'NONE',
#     'largestCriticalStrike': 0,
#     'largestKillingSpree': 3,
#     'largestMultiKill': 1,
#     'longestTimeSpentLiving': 298,
#     'magicDamageDealt': 1622,
#     'magicDamageDealtToChampions': 1068,
#     'magicDamageTaken': 8140,
#     'neutralMinionsKilled': 0,
#     'nexusKills': 0,
#     'nexusLost': 1,
#     'nexusTakedowns': 0,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'participantId': 2,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5002, 'flex': 5008, 'offense': 5008},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8128, 'var1': 563, 'var2': 12, 'var3': 0},
#         {'perk': 8126, 'var1': 346, 'var2': 0, 'var3': 0},
#         {'perk': 8138, 'var1': 18, 'var2': 0, 'var3': 0},
#         {'perk': 8106, 'var1': 5, 'var2': 0, 'var3': 0}],
#        'style': 8100},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8014, 'var1': 342, 'var2': 0, 'var3': 0},
#         {'perk': 9111, 'var1': 429, 'var2': 260, 'var3': 0}],
#        'style': 8000}]},
#     'physicalDamageDealt': 97090,
#     'physicalDamageDealtToChampions': 16814,
#     'physicalDamageTaken': 9427,
#     'profileIcon': 4933,
#     'puuid': 'C-AVvfUhz89vFwhvmqpVNopkGsrkfoT9H1AiSvPz3Yjfg4B6DeSrn89M-ngnIzS2LlBamPbIfGfkZw',
#     'quadraKills': 0,
#     'riotIdName': '',
#     'riotIdTagline': '',
#     'role': 'SUPPORT',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 117,
#     'spell2Casts': 26,
#     'spell3Casts': 24,
#     'spell4Casts': 8,
#     'summoner1Casts': 5,
#     'summoner1Id': 21,
#     'summoner2Casts': 6,
#     'summoner2Id': 4,
#     'summonerId': 'Cl-4wYdCIq2_jg39aTy-NQJH4HlyC9okhFMODvyTzPX_ug',
#     'summonerLevel': 245,
#     'summonerName': 'Renzhe',
#     'teamEarlySurrendered': False,
#     'teamId': 100,
#     'teamPosition': '',
#     'timeCCingOthers': 1,
#     'timePlayed': 990,
#     'totalDamageDealt': 101570,
#     'totalDamageDealtToChampions': 18196,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 18336,
#     'totalHeal': 474,
#     'totalHealsOnTeammates': 0,
#     'totalMinionsKilled': 104,
#     'totalTimeCCDealt': 38,
#     'totalTimeSpentDead': 255,
#     'totalUnitsHealed': 1,
#     'tripleKills': 0,
#     'trueDamageDealt': 2858,
#     'trueDamageDealtToChampions': 314,
#     'trueDamageTaken': 767,
#     'turretKills': 0,
#     'turretTakedowns': 1,
#     'turretsLost': 11,
#     'unrealKills': 0,
#     'visionScore': 0,
#     'visionWardsBoughtInGame': 0,
#     'wardsKilled': 0,
#     'wardsPlaced': 0,
#     'win': False},
#    {'assists': 6,
#     'baronKills': 0,
#     'bountyLevel': 0,
#     'champExperience': 19226,
#     'champLevel': 18,
#     'championId': 62,
#     'championName': 'MonkeyKing',
#     'championTransform': 0,
#     'consumablesPurchased': 0,
#     'damageDealtToBuildings': 8604,
#     'damageDealtToObjectives': 8604,
#     'damageDealtToTurrets': 8604,
#     'damageSelfMitigated': 39998,
#     'deaths': 12,
#     'detectorWardsPlaced': 0,
#     'doubleKills': 1,
#     'dragonKills': 0,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'goldEarned': 13813,
#     'goldSpent': 13800,
#     'individualPosition': 'Invalid',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 0,
#     'inhibitorsLost': 4,
#     'item0': 6632,
#     'item1': 6333,
#     'item2': 3111,
#     'item3': 3065,
#     'item4': 3053,
#     'item5': 0,
#     'item6': 3340,
#     'itemsPurchased': 21,
#     'killingSprees': 3,
#     'kills': 11,
#     'lane': 'NONE',
#     'largestCriticalStrike': 0,
#     'largestKillingSpree': 3,
#     'largestMultiKill': 2,
#     'longestTimeSpentLiving': 170,
#     'magicDamageDealt': 20831,
#     'magicDamageDealtToChampions': 3855,
#     'magicDamageTaken': 16149,
#     'neutralMinionsKilled': 0,
#     'nexusKills': 0,
#     'nexusLost': 1,
#     'nexusTakedowns': 0,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'participantId': 3,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5002, 'flex': 5008, 'offense': 5005},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8010, 'var1': 793, 'var2': 0, 'var3': 0},
#         {'perk': 9111, 'var1': 857, 'var2': 340, 'var3': 0},
#         {'perk': 9104, 'var1': 9, 'var2': 30, 'var3': 0},
#         {'perk': 8014, 'var1': 533, 'var2': 0, 'var3': 0}],
#        'style': 8000},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8143, 'var1': 1005, 'var2': 0, 'var3': 0},
#         {'perk': 8135, 'var1': 2584, 'var2': 5, 'var3': 0}],
#        'style': 8100}]},
#     'physicalDamageDealt': 52616,
#     'physicalDamageDealtToChampions': 20258,
#     'physicalDamageTaken': 16131,
#     'profileIcon': 29,
#     'puuid': 'gq-oLSjN4W0_nN_YlHauDtRlPRBgV_aJPda2XIvZavkjdu47PH2kArCAoLHmqgrYbXkWEMrvCFG_9Q',
#     'quadraKills': 0,
#     'riotIdName': '',
#     'riotIdTagline': '',
#     'role': 'SUPPORT',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 138,
#     'spell2Casts': 78,
#     'spell3Casts': 79,
#     'spell4Casts': 26,
#     'summoner1Casts': 4,
#     'summoner1Id': 6,
#     'summoner2Casts': 6,
#     'summoner2Id': 4,
#     'summonerId': '9Lu952rKSfjJ2WZOUuXCxcs_cy0D-BYicoSMcao0H1q6HlIp',
#     'summonerLevel': 123,
#     'summonerName': '좋아 쌀거같아',
#     'teamEarlySurrendered': False,
#     'teamId': 100,
#     'teamPosition': '',
#     'timeCCingOthers': 18,
#     'timePlayed': 990,
#     'totalDamageDealt': 73448,
#     'totalDamageDealtToChampions': 24113,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 39690,
#     'totalHeal': 10201,
#     'totalHealsOnTeammates': 0,
#     'totalMinionsKilled': 71,
#     'totalTimeCCDealt': 40,
#     'totalTimeSpentDead': 318,
#     'totalUnitsHealed': 1,
#     'tripleKills': 0,
#     'trueDamageDealt': 0,
#     'trueDamageDealtToChampions': 0,
#     'trueDamageTaken': 7409,
#     'turretKills': 3,
#     'turretTakedowns': 3,
#     'turretsLost': 11,
#     'unrealKills': 0,
#     'visionScore': 5,
#     'visionWardsBoughtInGame': 0,
#     'wardsKilled': 0,
#     'wardsPlaced': 4,
#     'win': False},
#    {'assists': 16,
#     'baronKills': 0,
#     'bountyLevel': 0,
#     'champExperience': 19981,
#     'champLevel': 18,
#     'championId': 350,
#     'championName': 'Yuumi',
#     'championTransform': 0,
#     'consumablesPurchased': 4,
#     'damageDealtToBuildings': 664,
#     'damageDealtToObjectives': 664,
#     'damageDealtToTurrets': 664,
#     'damageSelfMitigated': 4973,
#     'deaths': 9,
#     'detectorWardsPlaced': 0,
#     'doubleKills': 0,
#     'dragonKills': 0,
#     'firstBloodAssist': True,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'goldEarned': 10231,
#     'goldSpent': 10035,
#     'individualPosition': 'Invalid',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 0,
#     'inhibitorsLost': 4,
#     'item0': 3011,
#     'item1': 2065,
#     'item2': 3222,
#     'item3': 6616,
#     'item4': 1052,
#     'item5': 0,
#     'item6': 3340,
#     'itemsPurchased': 22,
#     'killingSprees': 0,
#     'kills': 1,
#     'lane': 'NONE',
#     'largestCriticalStrike': 0,
#     'largestKillingSpree': 0,
#     'largestMultiKill': 1,
#     'longestTimeSpentLiving': 165,
#     'magicDamageDealt': 9882,
#     'magicDamageDealtToChampions': 3558,
#     'magicDamageTaken': 5244,
#     'neutralMinionsKilled': 0,
#     'nexusKills': 0,
#     'nexusLost': 1,
#     'nexusTakedowns': 0,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'participantId': 4,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5002, 'flex': 5008, 'offense': 5008},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8214, 'var1': 637, 'var2': 3186, 'var3': 0},
#         {'perk': 8224, 'var1': 551, 'var2': 0, 'var3': 0},
#         {'perk': 8233, 'var1': 9, 'var2': 20, 'var3': 0},
#         {'perk': 8237, 'var1': 269, 'var2': 0, 'var3': 0}],
#        'style': 8200},
#       {'description': 'subStyle',
#        'selections': [{'perk': 9111, 'var1': 53, 'var2': 340, 'var3': 0},
#         {'perk': 8017, 'var1': 218, 'var2': 0, 'var3': 0}],
#        'style': 8000}]},
#     'physicalDamageDealt': 492,
#     'physicalDamageDealtToChampions': 103,
#     'physicalDamageTaken': 7233,
#     'profileIcon': 3542,
#     'puuid': 'itDgD4HT3UPbSlv-QdBcpC9kgi2fUVyM66sDy9aERoKQsVaXLJEwMjXs9jj36PyfnQ4qlt47KgEAhA',
#     'quadraKills': 0,
#     'riotIdName': '',
#     'riotIdTagline': '',
#     'role': 'SUPPORT',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 18,
#     'spell2Casts': 74,
#     'spell3Casts': 104,
#     'spell4Casts': 11,
#     'summoner1Casts': 11,
#     'summoner1Id': 14,
#     'summoner2Casts': 8,
#     'summoner2Id': 3,
#     'summonerId': 'armR0L5bl0hoep-1wAuXelprbtEgUS8lW8L-5bxI1FZIjkKe',
#     'summonerLevel': 101,
#     'summonerName': '자기야 어때',
#     'teamEarlySurrendered': False,
#     'teamId': 100,
#     'teamPosition': '',
#     'timeCCingOthers': 17,
#     'timePlayed': 990,
#     'totalDamageDealt': 12255,
#     'totalDamageDealtToChampions': 5541,
#     'totalDamageShieldedOnTeammates': 2585,
#     'totalDamageTaken': 13534,
#     'totalHeal': 8247,
#     'totalHealsOnTeammates': 6978,
#     'totalMinionsKilled': 5,
#     'totalTimeCCDealt': 35,
#     'totalTimeSpentDead': 269,
#     'totalUnitsHealed': 4,
#     'tripleKills': 0,
#     'trueDamageDealt': 1880,
#     'trueDamageDealtToChampions': 1880,
#     'trueDamageTaken': 1056,
#     'turretKills': 0,
#     'turretTakedowns': 3,
#     'turretsLost': 11,
#     'unrealKills': 0,
#     'visionScore': 10,
#     'visionWardsBoughtInGame': 0,
#     'wardsKilled': 0,
#     'wardsPlaced': 7,
#     'win': False},
#    {'assists': 9,
#     'baronKills': 0,
#     'bountyLevel': 0,
#     'champExperience': 20734,
#     'champLevel': 19,
#     'championId': 222,
#     'championName': 'Jinx',
#     'championTransform': 0,
#     'consumablesPurchased': 1,
#     'damageDealtToBuildings': 444,
#     'damageDealtToObjectives': 2825,
#     'damageDealtToTurrets': 444,
#     'damageSelfMitigated': 10259,
#     'deaths': 11,
#     'detectorWardsPlaced': 0,
#     'doubleKills': 0,
#     'dragonKills': 0,
#     'firstBloodAssist': True,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'goldEarned': 11479,
#     'goldSpent': 11300,
#     'individualPosition': 'Invalid',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 0,
#     'inhibitorsLost': 4,
#     'item0': 1055,
#     'item1': 6672,
#     'item2': 3006,
#     'item3': 3085,
#     'item4': 3031,
#     'item5': 1042,
#     'item6': 3364,
#     'itemsPurchased': 22,
#     'killingSprees': 0,
#     'kills': 3,
#     'lane': 'NONE',
#     'largestCriticalStrike': 513,
#     'largestKillingSpree': 0,
#     'largestMultiKill': 1,
#     'longestTimeSpentLiving': 249,
#     'magicDamageDealt': 1135,
#     'magicDamageDealtToChampions': 192,
#     'magicDamageTaken': 6700,
#     'neutralMinionsKilled': 16,
#     'nexusKills': 0,
#     'nexusLost': 1,
#     'nexusTakedowns': 0,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'participantId': 5,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5002, 'flex': 5008, 'offense': 5005},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8008, 'var1': 1, 'var2': 10, 'var3': 0},
#         {'perk': 9111, 'var1': 584, 'var2': 240, 'var3': 0},
#         {'perk': 9104, 'var1': 10, 'var2': 50, 'var3': 0},
#         {'perk': 8014, 'var1': 238, 'var2': 0, 'var3': 0}],
#        'style': 8000},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8139, 'var1': 955, 'var2': 0, 'var3': 0},
#         {'perk': 8135, 'var1': 1571, 'var2': 4, 'var3': 0}],
#        'style': 8100}]},
#     'physicalDamageDealt': 85184,
#     'physicalDamageDealtToChampions': 10812,
#     'physicalDamageTaken': 15177,
#     'profileIcon': 4871,
#     'puuid': 'Owr668vYJMN1opY1lsqLD6p4Fzsi9BA61NhEELAatPlBYQY6TUKbzOlzUrLjsd4fqackunukMY4Vrw',
#     'quadraKills': 0,
#     'riotIdName': '',
#     'riotIdTagline': '',
#     'role': 'SUPPORT',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 23,
#     'spell2Casts': 56,
#     'spell3Casts': 11,
#     'spell4Casts': 10,
#     'summoner1Casts': 4,
#     'summoner1Id': 1,
#     'summoner2Casts': 6,
#     'summoner2Id': 4,
#     'summonerId': '1e0axdy5TsBWIY7KApC7c8s-6Z330x1n9cWaCChlfFcoDO0',
#     'summonerLevel': 114,
#     'summonerName': '전반도',
#     'teamEarlySurrendered': False,
#     'teamId': 100,
#     'teamPosition': '',
#     'timeCCingOthers': 9,
#     'timePlayed': 990,
#     'totalDamageDealt': 89942,
#     'totalDamageDealtToChampions': 11676,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 22892,
#     'totalHeal': 1117,
#     'totalHealsOnTeammates': 0,
#     'totalMinionsKilled': 95,
#     'totalTimeCCDealt': 73,
#     'totalTimeSpentDead': 302,
#     'totalUnitsHealed': 1,
#     'tripleKills': 0,
#     'trueDamageDealt': 3622,
#     'trueDamageDealtToChampions': 671,
#     'trueDamageTaken': 1015,
#     'turretKills': 0,
#     'turretTakedowns': 0,
#     'turretsLost': 11,
#     'unrealKills': 0,
#     'visionScore': 19,
#     'visionWardsBoughtInGame': 0,
#     'wardsKilled': 3,
#     'wardsPlaced': 10,
#     'win': False},
#    {'assists': 4,
#     'baronKills': 1,
#     'bountyLevel': 1,
#     'champExperience': 23548,
#     'champLevel': 20,
#     'championId': 5,
#     'championName': 'XinZhao',
#     'championTransform': 0,
#     'consumablesPurchased': 0,
#     'damageDealtToBuildings': 4610,
#     'damageDealtToObjectives': 40684,
#     'damageDealtToTurrets': 4610,
#     'damageSelfMitigated': 19592,
#     'deaths': 6,
#     'detectorWardsPlaced': 0,
#     'doubleKills': 2,
#     'dragonKills': 3,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'goldEarned': 15350,
#     'goldSpent': 13650,
#     'individualPosition': 'Invalid',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 0,
#     'inhibitorsLost': 0,
#     'item0': 6671,
#     'item1': 3031,
#     'item2': 3072,
#     'item3': 6676,
#     'item4': 1029,
#     'item5': 0,
#     'item6': 3340,
#     'itemsPurchased': 17,
#     'killingSprees': 2,
#     'kills': 12,
#     'lane': 'NONE',
#     'largestCriticalStrike': 1272,
#     'largestKillingSpree': 8,
#     'largestMultiKill': 2,
#     'longestTimeSpentLiving': 473,
#     'magicDamageDealt': 12565,
#     'magicDamageDealtToChampions': 3500,
#     'magicDamageTaken': 2958,
#     'neutralMinionsKilled': 28,
#     'nexusKills': 1,
#     'nexusLost': 0,
#     'nexusTakedowns': 1,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'participantId': 6,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5002, 'flex': 5008, 'offense': 5005},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 9923, 'var1': 38, 'var2': 90, 'var3': 0},
#         {'perk': 8143, 'var1': 729, 'var2': 0, 'var3': 0},
#         {'perk': 8136, 'var1': 2, 'var2': 4, 'var3': 0},
#         {'perk': 8135, 'var1': 3291, 'var2': 5, 'var3': 0}],
#        'style': 8100},
#       {'description': 'subStyle',
#        'selections': [{'perk': 9111, 'var1': 704, 'var2': 320, 'var3': 0},
#         {'perk': 9104, 'var1': 7, 'var2': 20, 'var3': 0}],
#        'style': 8000}]},
#     'physicalDamageDealt': 111431,
#     'physicalDamageDealtToChampions': 19628,
#     'physicalDamageTaken': 18748,
#     'profileIcon': 775,
#     'puuid': 'e9a7OIfjXTOvKHkUfDBPMSh5UTpyD-wSzzukO5Q0p5gqnRMr7eUKsL0AL1OtkpNvRcQZHyWqQEoQXw',
#     'quadraKills': 0,
#     'riotIdName': '',
#     'riotIdTagline': '',
#     'role': 'SUPPORT',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 62,
#     'spell2Casts': 109,
#     'spell3Casts': 0,
#     'spell4Casts': 10,
#     'summoner1Casts': 6,
#     'summoner1Id': 4,
#     'summoner2Casts': 6,
#     'summoner2Id': 6,
#     'summonerId': 'Ej13-syHVO8U0lFsoX4qrOkNwGxDbcYW1DRPaLy4EEMvIbc',
#     'summonerLevel': 117,
#     'summonerName': 'mgardner',
#     'teamEarlySurrendered': False,
#     'teamId': 200,
#     'teamPosition': '',
#     'timeCCingOthers': 16,
#     'timePlayed': 990,
#     'totalDamageDealt': 125380,
#     'totalDamageDealtToChampions': 24027,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 22424,
#     'totalHeal': 4923,
#     'totalHealsOnTeammates': 0,
#     'totalMinionsKilled': 76,
#     'totalTimeCCDealt': 242,
#     'totalTimeSpentDead': 233,
#     'totalUnitsHealed': 1,
#     'tripleKills': 0,
#     'trueDamageDealt': 1383,
#     'trueDamageDealtToChampions': 898,
#     'trueDamageTaken': 717,
#     'turretKills': 2,
#     'turretTakedowns': 3,
#     'turretsLost': 4,
#     'unrealKills': 0,
#     'visionScore': 12,
#     'visionWardsBoughtInGame': 0,
#     'wardsKilled': 0,
#     'wardsPlaced': 8,
#     'win': True},
#    {'assists': 4,
#     'baronKills': 0,
#     'bountyLevel': 4,
#     'champExperience': 23110,
#     'champLevel': 20,
#     'championId': 421,
#     'championName': 'RekSai',
#     'championTransform': 0,
#     'consumablesPurchased': 4,
#     'damageDealtToBuildings': 2851,
#     'damageDealtToObjectives': 22770,
#     'damageDealtToTurrets': 2851,
#     'damageSelfMitigated': 8701,
#     'deaths': 5,
#     'detectorWardsPlaced': 0,
#     'doubleKills': 1,
#     'dragonKills': 1,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'goldEarned': 13858,
#     'goldSpent': 11675,
#     'individualPosition': 'Invalid',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 0,
#     'inhibitorsLost': 0,
#     'item0': 6676,
#     'item1': 6693,
#     'item2': 3095,
#     'item3': 1018,
#     'item4': 1037,
#     'item5': 3047,
#     'item6': 3340,
#     'itemsPurchased': 20,
#     'killingSprees': 3,
#     'kills': 9,
#     'lane': 'NONE',
#     'largestCriticalStrike': 1047,
#     'largestKillingSpree': 4,
#     'largestMultiKill': 2,
#     'longestTimeSpentLiving': 245,
#     'magicDamageDealt': 1003,
#     'magicDamageDealtToChampions': 163,
#     'magicDamageTaken': 2021,
#     'neutralMinionsKilled': 60,
#     'nexusKills': 0,
#     'nexusLost': 0,
#     'nexusTakedowns': 0,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'participantId': 7,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5002, 'flex': 5008, 'offense': 5005},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 9923, 'var1': 28, 'var2': 93, 'var3': 0},
#         {'perk': 8126, 'var1': 365, 'var2': 0, 'var3': 0},
#         {'perk': 8138, 'var1': 18, 'var2': 0, 'var3': 0},
#         {'perk': 8135, 'var1': 2214, 'var2': 5, 'var3': 0}],
#        'style': 8100},
#       {'description': 'subStyle',
#        'selections': [{'perk': 9104, 'var1': 12, 'var2': 10, 'var3': 0},
#         {'perk': 9111, 'var1': 328, 'var2': 260, 'var3': 0}],
#        'style': 8000}]},
#     'physicalDamageDealt': 93159,
#     'physicalDamageDealtToChampions': 8381,
#     'physicalDamageTaken': 10915,
#     'profileIcon': 4903,
#     'puuid': 'q3_A5EJHpKGT3QkuafIOXgtKvYrmLHZH99DgZTFVR5FJzVu2JQT5jKd3Dvo7zMzTaRh2CFGx27CGGg',
#     'quadraKills': 0,
#     'riotIdName': '',
#     'riotIdTagline': '',
#     'role': 'SUPPORT',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 125,
#     'spell2Casts': 76,
#     'spell3Casts': 78,
#     'spell4Casts': 6,
#     'summoner1Casts': 10,
#     'summoner1Id': 14,
#     'summoner2Casts': 3,
#     'summoner2Id': 4,
#     'summonerId': 'wvGtGZoCdD7hCfZpTeU5dfBKGAGjZo73DL-SSwOhb-9hLUg',
#     'summonerLevel': 209,
#     'summonerName': 'YMD 렉사이',
#     'teamEarlySurrendered': False,
#     'teamId': 200,
#     'teamPosition': '',
#     'timeCCingOthers': 13,
#     'timePlayed': 990,
#     'totalDamageDealt': 107263,
#     'totalDamageDealtToChampions': 12982,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 13451,
#     'totalHeal': 1618,
#     'totalHealsOnTeammates': 0,
#     'totalMinionsKilled': 33,
#     'totalTimeCCDealt': 114,
#     'totalTimeSpentDead': 158,
#     'totalUnitsHealed': 1,
#     'tripleKills': 0,
#     'trueDamageDealt': 13100,
#     'trueDamageDealtToChampions': 4438,
#     'trueDamageTaken': 513,
#     'turretKills': 2,
#     'turretTakedowns': 2,
#     'turretsLost': 4,
#     'unrealKills': 0,
#     'visionScore': 19,
#     'visionWardsBoughtInGame': 0,
#     'wardsKilled': 1,
#     'wardsPlaced': 12,
#     'win': True},
#    {'assists': 8,
#     'baronKills': 0,
#     'bountyLevel': 0,
#     'champExperience': 22943,
#     'champLevel': 20,
#     'championId': 67,
#     'championName': 'Vayne',
#     'championTransform': 0,
#     'consumablesPurchased': 1,
#     'damageDealtToBuildings': 14301,
#     'damageDealtToObjectives': 25983,
#     'damageDealtToTurrets': 14301,
#     'damageSelfMitigated': 26651,
#     'deaths': 9,
#     'detectorWardsPlaced': 0,
#     'doubleKills': 2,
#     'dragonKills': 0,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': True,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'goldEarned': 16699,
#     'goldSpent': 15575,
#     'individualPosition': 'Invalid',
#     'inhibitorKills': 2,
#     'inhibitorTakedowns': 2,
#     'inhibitorsLost': 0,
#     'item0': 6673,
#     'item1': 3153,
#     'item2': 3082,
#     'item3': 3046,
#     'item4': 3072,
#     'item5': 3047,
#     'item6': 3340,
#     'itemsPurchased': 15,
#     'killingSprees': 4,
#     'kills': 14,
#     'lane': 'NONE',
#     'largestCriticalStrike': 739,
#     'largestKillingSpree': 5,
#     'largestMultiKill': 2,
#     'longestTimeSpentLiving': 138,
#     'magicDamageDealt': 244,
#     'magicDamageDealtToChampions': 244,
#     'magicDamageTaken': 3489,
#     'neutralMinionsKilled': 0,
#     'nexusKills': 0,
#     'nexusLost': 0,
#     'nexusTakedowns': 0,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'participantId': 8,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5002, 'flex': 5008, 'offense': 5005},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8005, 'var1': 2289, 'var2': 1136, 'var3': 1153},
#         {'perk': 9111, 'var1': 929, 'var2': 440, 'var3': 0},
#         {'perk': 9103, 'var1': 8, 'var2': 50, 'var3': 0},
#         {'perk': 8014, 'var1': 681, 'var2': 0, 'var3': 0}],
#        'style': 8000},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8139, 'var1': 1284, 'var2': 0, 'var3': 0},
#         {'perk': 8135, 'var1': 2999, 'var2': 5, 'var3': 0}],
#        'style': 8100}]},
#     'physicalDamageDealt': 82308,
#     'physicalDamageDealtToChampions': 25999,
#     'physicalDamageTaken': 20812,
#     'profileIcon': 4929,
#     'puuid': 'DWj5t4f_Xbv5DOdjIx3VesHeWnh7xtgZSoH0mK7e3Hn5XCQZ-GJsgfQqjt6CKykgZEzCKMbAFBk00w',
#     'quadraKills': 0,
#     'riotIdName': '',
#     'riotIdTagline': '',
#     'role': 'SUPPORT',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 133,
#     'spell2Casts': 0,
#     'spell3Casts': 22,
#     'spell4Casts': 15,
#     'summoner1Casts': 7,
#     'summoner1Id': 4,
#     'summoner2Casts': 9,
#     'summoner2Id': 7,
#     'summonerId': 'wh0VyjZjV34eBJnP_T6iH1k2ck1q_ewP3TPALuYtmMYZjA',
#     'summonerLevel': 292,
#     'summonerName': 'C Gu Ri',
#     'teamEarlySurrendered': False,
#     'teamId': 200,
#     'teamPosition': '',
#     'timeCCingOthers': 13,
#     'timePlayed': 990,
#     'totalDamageDealt': 98557,
#     'totalDamageDealtToChampions': 37676,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 25200,
#     'totalHeal': 2939,
#     'totalHealsOnTeammates': 231,
#     'totalMinionsKilled': 66,
#     'totalTimeCCDealt': 17,
#     'totalTimeSpentDead': 239,
#     'totalUnitsHealed': 3,
#     'tripleKills': 0,
#     'trueDamageDealt': 16003,
#     'trueDamageDealtToChampions': 11431,
#     'trueDamageTaken': 899,
#     'turretKills': 4,
#     'turretTakedowns': 6,
#     'turretsLost': 4,
#     'unrealKills': 0,
#     'visionScore': 21,
#     'visionWardsBoughtInGame': 1,
#     'wardsKilled': 1,
#     'wardsPlaced': 13,
#     'win': True},
#    {'assists': 14,
#     'baronKills': 0,
#     'bountyLevel': 0,
#     'champExperience': 21191,
#     'champLevel': 19,
#     'championId': 147,
#     'championName': 'Seraphine',
#     'championTransform': 0,
#     'consumablesPurchased': 0,
#     'damageDealtToBuildings': 8477,
#     'damageDealtToObjectives': 8477,
#     'damageDealtToTurrets': 8477,
#     'damageSelfMitigated': 13080,
#     'deaths': 7,
#     'detectorWardsPlaced': 0,
#     'doubleKills': 0,
#     'dragonKills': 0,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': True,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'goldEarned': 14715,
#     'goldSpent': 14200,
#     'individualPosition': 'Invalid',
#     'inhibitorKills': 2,
#     'inhibitorTakedowns': 2,
#     'inhibitorsLost': 0,
#     'item0': 6655,
#     'item1': 3165,
#     'item2': 3116,
#     'item3': 3100,
#     'item4': 1058,
#     'item5': 1058,
#     'item6': 3363,
#     'itemsPurchased': 20,
#     'killingSprees': 1,
#     'kills': 6,
#     'lane': 'NONE',
#     'largestCriticalStrike': 0,
#     'largestKillingSpree': 3,
#     'largestMultiKill': 1,
#     'longestTimeSpentLiving': 205,
#     'magicDamageDealt': 100727,
#     'magicDamageDealtToChampions': 24100,
#     'magicDamageTaken': 2313,
#     'neutralMinionsKilled': 1,
#     'nexusKills': 0,
#     'nexusLost': 0,
#     'nexusTakedowns': 0,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'participantId': 9,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5002, 'flex': 5008, 'offense': 5008},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8128, 'var1': 810, 'var2': 20, 'var3': 0},
#         {'perk': 8126, 'var1': 625, 'var2': 0, 'var3': 0},
#         {'perk': 8138, 'var1': 30, 'var2': 0, 'var3': 0},
#         {'perk': 8135, 'var1': 2643, 'var2': 5, 'var3': 0}],
#        'style': 8100},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8233, 'var1': 8, 'var2': 20, 'var3': 0},
#         {'perk': 8237, 'var1': 480, 'var2': 0, 'var3': 0}],
#        'style': 8200}]},
#     'physicalDamageDealt': 4076,
#     'physicalDamageDealtToChampions': 1641,
#     'physicalDamageTaken': 16898,
#     'profileIcon': 4863,
#     'puuid': 'ZRQMRm9bJeet28u08d7A0CiShrV4hJMljeeewRsxGE-5mOm-ElPIQlplK6kkMf-dM-mWAMcA2ywlzQ',
#     'quadraKills': 0,
#     'riotIdName': '',
#     'riotIdTagline': '',
#     'role': 'SUPPORT',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 145,
#     'spell2Casts': 93,
#     'spell3Casts': 140,
#     'spell4Casts': 13,
#     'summoner1Casts': 11,
#     'summoner1Id': 6,
#     'summoner2Casts': 7,
#     'summoner2Id': 4,
#     'summonerId': 'd2WlC7yRaw7XBT3aY61bJVX0vH1PTQu1CC_UbqnXezGAvvI',
#     'summonerLevel': 169,
#     'summonerName': 'midplayer or AFK',
#     'teamEarlySurrendered': False,
#     'teamId': 200,
#     'teamPosition': '',
#     'timeCCingOthers': 38,
#     'timePlayed': 990,
#     'totalDamageDealt': 105439,
#     'totalDamageDealtToChampions': 26309,
#     'totalDamageShieldedOnTeammates': 1538,
#     'totalDamageTaken': 20122,
#     'totalHeal': 2137,
#     'totalHealsOnTeammates': 913,
#     'totalMinionsKilled': 90,
#     'totalTimeCCDealt': 340,
#     'totalTimeSpentDead': 251,
#     'totalUnitsHealed': 3,
#     'tripleKills': 0,
#     'trueDamageDealt': 635,
#     'trueDamageDealtToChampions': 566,
#     'trueDamageTaken': 911,
#     'turretKills': 3,
#     'turretTakedowns': 7,
#     'turretsLost': 4,
#     'unrealKills': 0,
#     'visionScore': 7,
#     'visionWardsBoughtInGame': 0,
#     'wardsKilled': 0,
#     'wardsPlaced': 4,
#     'win': True},
#    {'assists': 8,
#     'baronKills': 0,
#     'bountyLevel': 0,
#     'champExperience': 21679,
#     'champLevel': 19,
#     'championId': 127,
#     'championName': 'Lissandra',
#     'championTransform': 0,
#     'consumablesPurchased': 0,
#     'damageDealtToBuildings': 3919,
#     'damageDealtToObjectives': 13280,
#     'damageDealtToTurrets': 3919,
#     'damageSelfMitigated': 6097,
#     'deaths': 4,
#     'detectorWardsPlaced': 0,
#     'doubleKills': 1,
#     'dragonKills': 0,
#     'firstBloodAssist': False,
#     'firstBloodKill': False,
#     'firstTowerAssist': False,
#     'firstTowerKill': False,
#     'gameEndedInEarlySurrender': False,
#     'gameEndedInSurrender': False,
#     'goldEarned': 16075,
#     'goldSpent': 14400,
#     'individualPosition': 'Invalid',
#     'inhibitorKills': 0,
#     'inhibitorTakedowns': 0,
#     'inhibitorsLost': 0,
#     'item0': 6655,
#     'item1': 4628,
#     'item2': 3089,
#     'item3': 3020,
#     'item4': 3135,
#     'item5': 3916,
#     'item6': 3340,
#     'itemsPurchased': 17,
#     'killingSprees': 2,
#     'kills': 8,
#     'lane': 'NONE',
#     'largestCriticalStrike': 0,
#     'largestKillingSpree': 5,
#     'largestMultiKill': 2,
#     'longestTimeSpentLiving': 471,
#     'magicDamageDealt': 183218,
#     'magicDamageDealtToChampions': 24364,
#     'magicDamageTaken': 2943,
#     'neutralMinionsKilled': 67,
#     'nexusKills': 0,
#     'nexusLost': 0,
#     'nexusTakedowns': 0,
#     'objectivesStolen': 0,
#     'objectivesStolenAssists': 0,
#     'participantId': 10,
#     'pentaKills': 0,
#     'perks': {'statPerks': {'defense': 5001, 'flex': 5008, 'offense': 5008},
#      'styles': [{'description': 'primaryStyle',
#        'selections': [{'perk': 8112, 'var1': 1365, 'var2': 0, 'var3': 0},
#         {'perk': 8126, 'var1': 556, 'var2': 0, 'var3': 0},
#         {'perk': 8138, 'var1': 30, 'var2': 0, 'var3': 0},
#         {'perk': 8106, 'var1': 4, 'var2': 0, 'var3': 0}],
#        'style': 8100},
#       {'description': 'subStyle',
#        'selections': [{'perk': 8014, 'var1': 708, 'var2': 0, 'var3': 0},
#         {'perk': 9103, 'var1': 10, 'var2': 50, 'var3': 0}],
#        'style': 8000}]},
#     'physicalDamageDealt': 1808,
#     'physicalDamageDealtToChampions': 254,
#     'physicalDamageTaken': 12454,
#     'profileIcon': 4863,
#     'puuid': 'gyMsX59Ug-sKKSE3DG-ocPq16wew9bsFfBuiSBwTOX-gAYbgywwMNLyTOCmBUvCLZrkhPDtaLD62zA',
#     'quadraKills': 0,
#     'riotIdName': '',
#     'riotIdTagline': '',
#     'role': 'SUPPORT',
#     'sightWardsBoughtInGame': 0,
#     'spell1Casts': 151,
#     'spell2Casts': 64,
#     'spell3Casts': 106,
#     'spell4Casts': 13,
#     'summoner1Casts': 6,
#     'summoner1Id': 4,
#     'summoner2Casts': 8,
#     'summoner2Id': 6,
#     'summonerId': 'duSHDW0os8Ew82OY4bLCj7Wov3uTS7EHkD128VschvzQGbE',
#     'summonerLevel': 195,
#     'summonerName': '니니 아님',
#     'teamEarlySurrendered': False,
#     'teamId': 200,
#     'teamPosition': '',
#     'timeCCingOthers': 28,
#     'timePlayed': 990,
#     'totalDamageDealt': 185962,
#     'totalDamageDealtToChampions': 25278,
#     'totalDamageShieldedOnTeammates': 0,
#     'totalDamageTaken': 16231,
#     'totalHeal': 1969,
#     'totalHealsOnTeammates': 0,
#     'totalMinionsKilled': 118,
#     'totalTimeCCDealt': 217,
#     'totalTimeSpentDead': 102,
#     'totalUnitsHealed': 1,
#     'tripleKills': 0,
#     'trueDamageDealt': 934,
#     'trueDamageDealtToChampions': 659,
#     'trueDamageTaken': 833,
#     'turretKills': 0,
#     'turretTakedowns': 1,
#     'turretsLost': 4,
#     'unrealKills': 0,
#     'visionScore': 29,
#     'visionWardsBoughtInGame': 0,
#     'wardsKilled': 0,
#     'wardsPlaced': 21,
#     'win': True}],
#   'platformId': 'KR',
#   'queueId': 900,
#   'teams': [{'bans': [{'championId': 238, 'pickTurn': 1},
#      {'championId': 35, 'pickTurn': 2},
#      {'championId': 1, 'pickTurn': 3},
#      {'championId': 555, 'pickTurn': 4},
#      {'championId': 48, 'pickTurn': 5}],
#     'objectives': {'baron': {'first': False, 'kills': 0},
#      'champion': {'first': True, 'kills': 31},
#      'dragon': {'first': False, 'kills': 0},
#      'inhibitor': {'first': False, 'kills': 0},
#      'riftHerald': {'first': False, 'kills': 0},
#      'tower': {'first': False, 'kills': 4}},
#     'teamId': 100,
#     'win': False},
#    {'bans': [{'championId': 114, 'pickTurn': 6},
#      {'championId': 238, 'pickTurn': 7},
#      {'championId': -1, 'pickTurn': 8},
#      {'championId': 81, 'pickTurn': 9},
#      {'championId': 517, 'pickTurn': 10}],
#     'objectives': {'baron': {'first': True, 'kills': 1},
#      'champion': {'first': False, 'kills': 49},
#      'dragon': {'first': True, 'kills': 4},
#      'inhibitor': {'first': True, 'kills': 4},
#      'riftHerald': {'first': False, 'kills': 0},
#      'tower': {'first': True, 'kills': 11}},
#     'teamId': 200,
#     'win': True}],
#   'tournamentCode': ''},
#  'metadata': {'dataVersion': '2',
#   'matchId': 'KR_5507417922',
#   'participants': ['LX7j68CtwzgVjJ17lZKmCyHTp8GKGjlGY5pjOYdWtCU3ag9IydXCG7U09cxy4ynZxKV3DXzgMHCr_A',
#    'C-AVvfUhz89vFwhvmqpVNopkGsrkfoT9H1AiSvPz3Yjfg4B6DeSrn89M-ngnIzS2LlBamPbIfGfkZw',
#    'gq-oLSjN4W0_nN_YlHauDtRlPRBgV_aJPda2XIvZavkjdu47PH2kArCAoLHmqgrYbXkWEMrvCFG_9Q',
#    'itDgD4HT3UPbSlv-QdBcpC9kgi2fUVyM66sDy9aERoKQsVaXLJEwMjXs9jj36PyfnQ4qlt47KgEAhA',
#    'Owr668vYJMN1opY1lsqLD6p4Fzsi9BA61NhEELAatPlBYQY6TUKbzOlzUrLjsd4fqackunukMY4Vrw',
#    'e9a7OIfjXTOvKHkUfDBPMSh5UTpyD-wSzzukO5Q0p5gqnRMr7eUKsL0AL1OtkpNvRcQZHyWqQEoQXw',
#    'q3_A5EJHpKGT3QkuafIOXgtKvYrmLHZH99DgZTFVR5FJzVu2JQT5jKd3Dvo7zMzTaRh2CFGx27CGGg',
#    'DWj5t4f_Xbv5DOdjIx3VesHeWnh7xtgZSoH0mK7e3Hn5XCQZ-GJsgfQqjt6CKykgZEzCKMbAFBk00w',
#    'ZRQMRm9bJeet28u08d7A0CiShrV4hJMljeeewRsxGE-5mOm-ElPIQlplK6kkMf-dM-mWAMcA2ywlzQ',
#    'gyMsX59Ug-sKKSE3DG-ocPq16wew9bsFfBuiSBwTOX-gAYbgywwMNLyTOCmBUvCLZrkhPDtaLD62zA']}}

# %%
# 모든 column print하게 설정 변경
pd.set_option('display.max_columns',None)

# %%
# DataFrame으로 변환
df = pd.DataFrame(r.json()['info']['participants'])

# %%
# 확인할 변수
COLUMNS = ['summonerName','teamId','championName','summoner1Id','summoner2Id','win',
          'item0','item1','item2','item3','item4','item5','item6',
          'kills','deaths','assists','totalDamageDealtToChampions','totalDamageTaken','goldEarned']

# %%
# 확인할 변수만 가져와서 새로운 DataFrame에 저장
df2 = df[COLUMNS]

# %%
# 최종 추출 형태 확인
df2

# %%
df3 = df2.copy()

# %%
# 각종 개인 지표 추가해서 새로운 DataFrame에 저장
# KDA = (K + A) / D
# GPM = goldEarned / (gameDuration_In_Munite)
# DPM = damageDealt / (gameDuration_In_Munite)
# DTPM = damageTaken / (gameDuration_In_Munite)
df3['KDA'] = (df3['kills'] + df3['assists']) / df3['deaths']
df3['GPM'] = df3['goldEarned'] / r.json()['info']['gameDuration'] * 60
df3['DPM'] = df3['totalDamageDealtToChampions'] / r.json()['info']['gameDuration'] * 60
df3['DTPM'] = df3['totalDamageTaken'] / r.json()['info']['gameDuration'] * 60

# %%
df3

# %%
# 숫자로 된 각종 Key값에 대한 Value 가져오기
spell_constant = requests.get("http://ddragon.leagueoflegends.com/cdn/11.20.1/data/ko_KR/summoner.json")
item_constant = requests.get("http://ddragon.leagueoflegends.com/cdn/11.20.1/data/ko_KR/item.json")

# %%
spell_constant.json()

# %%
# Json 파일을 DataFrame으로 변환
spell_df = pd.DataFrame(spell_constant.json()['data']).T[['key','name']]
item_df = pd.DataFrame(item_constant.json()['data']).T['name'].rename_axis("key").reset_index()

# 변수형 문자 -> 숫자
spell_df['key'] = pd.to_numeric(spell_df['key'])
item_df['key'] = pd.to_numeric(item_df['key'])

# %%
item_df

# %%
df4 = df3.copy()

# %%
df4 = pd.merge(df4,spell_df,how = 'left', left_on = 'summoner1Id', right_on = 'key').\
rename(columns={'name': 'D'})
df4 = pd.merge(df4,spell_df,how = 'left', left_on = 'summoner2Id', right_on = 'key').\
rename(columns={'name': 'F'})

# %%
df4 = pd.merge(df4,item_df,how = 'left', left_on = 'item0', right_on = 'key').\
rename(columns={'name': 'Item1'})
df4 = pd.merge(df4,item_df,how = 'left', left_on = 'item1', right_on = 'key').\
rename(columns={'name': 'Item2'})
df4 = pd.merge(df4,item_df,how = 'left', left_on = 'item2', right_on = 'key').\
rename(columns={'name': 'Item3'})
df4 = pd.merge(df4,item_df,how = 'left', left_on = 'item3', right_on = 'key').\
rename(columns={'name': 'Item4'})
df4 = pd.merge(df4,item_df,how = 'left', left_on = 'item4', right_on = 'key').\
rename(columns={'name': 'Item5'})
df4 = pd.merge(df4,item_df,how = 'left', left_on = 'item5', right_on = 'key').\
rename(columns={'name': 'Item6'})
df4 = pd.merge(df4,item_df,how = 'left', left_on = 'item6', right_on = 'key').\
rename(columns={'name': 'Trinket'})

# %%
df4

# %%
# 확인할 변수
COLUMNS_NEW = ['summonerName','teamId','championName','D','F','win',
               'Item1','Item2','Item3','Item4','Item5','Item6','Trinket',
               'KDA','kills','deaths','assists','GPM','DPM','DTPM']

# %%
df5 = df4[COLUMNS_NEW]

# %%
df5
