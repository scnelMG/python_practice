# %%
import pandas as pd
import numpy as np
import requests
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("1124ver_championStats.csv",index_col = 0)

# %%
data.sort_values(by=['attackspeedperlevel'], ascending=False)
# Out:
#            championName  versionIndex        version     hp  hpperlevel  \
# championId
# 150                Gnar         11.23  11.23.409.111  510.0          65
# 51              Caitlyn         11.23  11.23.409.111  510.0          93
# 110               Varus         11.23  11.23.409.111  530.0          91
# 166              Akshan         11.23  11.23.409.111  560.0          90
# 235               Senna         11.23  11.23.409.111  520.0          75
# ...                 ...           ...            ...    ...         ...
# 147           Seraphine         11.23  11.23.409.111  500.0          90
# 711                 Vex         11.23  11.23.409.111  520.0          90
# 350               Yuumi         11.23  11.23.409.111  480.0          70
# 222                Jinx         11.23  11.23.409.111  610.0          86
# 202                Jhin         11.23  11.23.409.111  585.0          93
#
#                mp  mpperlevel  movespeed  armor  armorperlevel  ...  \
# ...

# %%
# Out:
# championId
# 1      1.36
# 2      2.70
# 3      1.50
# 4      3.22
# 5      3.50
#        ...
# 711    1.00
# 777    3.50
# 875    1.75
# 876    2.70
# 887    2.25
# Name: attackspeedperlevel, Length: 157, dtype: float64
